# %% [markdown]
# <a href="https://colab.research.google.com/github/JyotiSingh0996/Projects-of-data-science-by-Jyoti-Singh/blob/main/spotify_dataset_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
music_df = pd.read_csv('/content/drive/MyDrive/archive (5).zip')

# %%
music_df.head(2)
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
#
#   track_artist  track_popularity          track_album_id  \
# 0   Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1     Maroon 5                67  63rPSO264uRjW1X5E6cWv6
#
#                                     track_album_name track_album_release_date  \
# 0  I Don't Care (with Justin Bieber) [Loud Luxury...               2019-06-14
# 1                    Memories (Dillon Francis Remix)               2019-12-13
#
#   playlist_name             playlist_id playlist_genre  ... key  loudness  \
# 0     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   6    -2.634
# 1     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...  11    -4.969
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# ...

# %%
music_df.transpose()
# Out:
#                                                                       0      \
# track_id                                             6f807x0ima9a1j3VPbc7VN
# track_name                I Don't Care (with Justin Bieber) - Loud Luxur...
# track_artist                                                     Ed Sheeran
# track_popularity                                                         66
# track_album_id                                       2oCs0DGTsRO98Gh5ZSl2Cx
# track_album_name          I Don't Care (with Justin Bieber) [Loud Luxury...
# track_album_release_date                                         2019-06-14
# playlist_name                                                     Pop Remix
# playlist_id                                          37i9dQZF1DXcZDD7cfEKhW
# playlist_genre                                                          pop
# playlist_subgenre                                                 dance pop
# ...

# %%
music_df['playlist_subgenre'].unique()
# Out:
# array(['dance pop', 'post-teen pop', 'electropop', 'indie poptimism',
#        'hip hop', 'southern hip hop', 'gangster rap', 'trap',
#        'album rock', 'classic rock', 'permanent wave', 'hard rock',
#        'tropical', 'latin pop', 'reggaeton', 'latin hip hop',
#        'urban contemporary', 'hip pop', 'new jack swing', 'neo soul',
#        'electro house', 'big room', 'pop edm',
#        'progressive electro house'], dtype=object)

# %%
music_df.shape
# Out:
# (32833, 23)

# %%
music_df.describe()
# Out:
#        track_popularity  danceability        energy           key  \
# count      32833.000000  32833.000000  32833.000000  32833.000000
# mean          42.477081      0.654850      0.698619      5.374471
# std           24.984074      0.145085      0.180910      3.611657
# min            0.000000      0.000000      0.000175      0.000000
# 25%           24.000000      0.563000      0.581000      2.000000
# 50%           45.000000      0.672000      0.721000      6.000000
# 75%           62.000000      0.761000      0.840000      9.000000
# max          100.000000      0.983000      1.000000     11.000000
#
#            loudness          mode   speechiness  acousticness  \
# count  32833.000000  32833.000000  32833.000000  32833.000000
# mean      -6.719499      0.565711      0.107068      0.175334
# std        2.988436      0.495671      0.101314      0.219633
# min      -46.448000      0.000000      0.000000      0.000000
# ...

# %%
music_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32833 entries, 0 to 32832
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  32833 non-null  object
#  1   track_name                32828 non-null  object
#  2   track_artist              32828 non-null  object
#  3   track_popularity          32833 non-null  int64
#  4   track_album_id            32833 non-null  object
#  5   track_album_name          32828 non-null  object
#  6   track_album_release_date  32833 non-null  object
#  7   playlist_name             32833 non-null  object
#  8   playlist_id               32833 non-null  object
#  9   playlist_genre            32833 non-null  object
#  10  playlist_subgenre         32833 non-null  object
#  11  danceability              32833 non-null  float64
#  12  energy                    32833 non-null  float64
# ...

# %%
music_df.isna().sum()
# Out:
# track_id                    0
# track_name                  5
# track_artist                5
# track_popularity            0
# track_album_id              0
# track_album_name            5
# track_album_release_date    0
# playlist_name               0
# playlist_id                 0
# playlist_genre              0
# playlist_subgenre           0
# danceability                0
# energy                      0
# key                         0
# loudness                    0
# mode                        0
# speechiness                 0
# acousticness                0
# instrumentalness            0
# liveness                    0
# valence                     0
# tempo                       0
# duration_ms                 0
# dtype: int64

# %%
music_df.dropna(inplace=True)

# %%
music_df[music_df['playlist_genre']=='pop']
# Out:
#                     track_id  \
# 0     6f807x0ima9a1j3VPbc7VN
# 1     0r7CVbZTWZgbTCYdfa2P31
# 2     1z1Hg7Vb0AhHDiEmnDE79l
# 3     75FpbthrwQmzHlBJLuGdC7
# 4     1e8PAfcKUYoKkxPhrHqw4x
# ...                      ...
# 5502  27W2xRl5A5vUTuj0kX6YmW
# 5503  087B7ONFOiKkkMVmg83md0
# 5504  3jl1I9gvCXo5V9hu4hYGLY
# 5505  5t7SHDPq9Ef7O92chdneBs
# 5506  7j3nbSiaWphYU2cFgyQXd9
#
#                                              track_name      track_artist  \
# 0     I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran
# 1                       Memories - Dillon Francis Remix          Maroon 5
# 2                       All the Time - Don Diablo Remix      Zara Larsson
# 3                     Call You Mine - Keanu Silva Remix  The Chainsmokers
# 4               Someone You Loved - Future Humans Remix     Lewis Capaldi
# ...                                                 ...               ...
# 5502                                           Lovesick    Fickle Friends
# ...

# %%
music_df['playlist_genre'].value_counts()
# Out:
# edm      6043
# rap      5743
# pop      5507
# r&b      5431
# latin    5153
# rock     4951
# Name: playlist_genre, dtype: int64

# %%
music_df.duplicated().sum()
# Out:
# 0

# %%
music_df['key'].unique()
# Out:
# array([ 6, 11,  1,  7,  8,  5,  4,  2,  0, 10,  9,  3])

# %%
music_df.drop_duplicates(inplace=True)

# %%
music_df['track_name'][0]
# Out:
# "I Don't Care (with Justin Bieber) - Loud Luxury Remix"

# %%
music_df.shape
# Out:
# (32828, 23)

# %%
music_df[music_df['track_popularity']==0]
# Out:
#                      track_id  \
# 476    1gsb4CFzUMERAkfzAKwrZu
# 772    4yEXem27DzCg8xytvvO3E9
# 801    7vHkU1H73z5NVbGTIyI1DG
# 883    3decfgk2pFkvCzYUFj6ssf
# 934    5KHbu2Go6NBryS0h0TpTNJ
# ...                       ...
# 32800  5yl2YyDgcpERTZoZHD9Etl
# 32810  0ZAPuWOQiiY0nGbLPlozT8
# 32813  5sYzg83Vy4IW4TfE9jwk8g
# 32821  3fgNmvYq0QU5aFHDUMa4cm
# 32822  00UpV14MDfk4CvrMbFvqji
#
#                                               track_name         track_artist  \
# 476                                                Siren                SUNMI
# 772                                  Lollipop (Candyman)                 Aqua
# 801                                     Around The World                 Aqua
# 883                                            I'm Yours  Influencers Worship
# 934                                        Talk About It              Bancali
# ...                                                  ...                  ...
# ...

# %%
music_df.isnull().sum()
# Out:
# track_id                    0
# track_name                  0
# track_artist                0
# track_popularity            0
# track_album_id              0
# track_album_name            0
# track_album_release_date    0
# playlist_name               0
# playlist_id                 0
# playlist_genre              0
# playlist_subgenre           0
# danceability                0
# energy                      0
# key                         0
# loudness                    0
# mode                        0
# speechiness                 0
# acousticness                0
# instrumentalness            0
# liveness                    0
# valence                     0
# tempo                       0
# duration_ms                 0
# dtype: int64

# %%
music_df.columns
# Out:
# Index(['track_id', 'track_name', 'track_artist', 'track_popularity',
#        'track_album_id', 'track_album_name', 'track_album_release_date',
#        'playlist_name', 'playlist_id', 'playlist_genre', 'playlist_subgenre',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms'],
#       dtype='object')

# %%
music_df['year'] = pd.DatetimeIndex(music_df['track_album_release_date']).year

# %%
new_music_df = music_df[['track_id','track_name','track_artist','track_popularity','year','track_album_name','playlist_name','playlist_subgenre','loudness']]

# %%
new_music_df.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity  year  \
# 0        Ed Sheeran                66  2019
# 1          Maroon 5                67  2019
# 2      Zara Larsson                70  2019
# 3  The Chainsmokers                60  2019
# 4     Lewis Capaldi                69  2019
#
#                                     track_album_name playlist_name  \
# 0  I Don't Care (with Justin Bieber) [Loud Luxury...     Pop Remix
# 1                    Memories (Dillon Francis Remix)     Pop Remix
# ...

# %%
#music_df['playlist_name'].unique()

# %%
music_df['playlist_genre'].unique()
# Out:
# array(['pop', 'rap', 'rock', 'latin', 'r&b', 'edm'], dtype=object)

# %%
# track_id

# %%
music_df['playlist_subgenre'].unique()
# Out:
# array(['dance pop', 'post-teen pop', 'electropop', 'indie poptimism',
#        'hip hop', 'southern hip hop', 'gangster rap', 'trap',
#        'album rock', 'classic rock', 'permanent wave', 'hard rock',
#        'tropical', 'latin pop', 'reggaeton', 'latin hip hop',
#        'urban contemporary', 'hip pop', 'new jack swing', 'neo soul',
#        'electro house', 'big room', 'pop edm',
#        'progressive electro house'], dtype=object)

# %%
song_grouped = new_music_df.groupby(['track_name']).agg({'track_popularity':'count'}).reset_index()

# %%
song_grouped
# Out:
#                                    track_name  track_popularity
# 0      "I TRIED FOR YEARS... NOBODY LISTENED"                 1
# 1                         "This Is Seagull…."                 1
# 2                                   #1 Stunna                 2
# 3                                     #NAKAMA                 1
# 4                                    #Natural                 1
# ...                                       ...               ...
# 23444                            숙녀 (淑女) Lady                 1
# 23445                                      쉼표                 1
# 23446                             중독 Overdose                 1
# 23447                          피카부 Peek-A-Boo                 1
# 23448                         하드캐리 Hard Carry                 1
#
# [23449 rows x 2 columns]

# %%
grouped_sum = song_grouped['track_popularity'].sum()
song_grouped['percentage'] = (song_grouped['track_popularity']/ grouped_sum)*100
song_grouped.sort_values(['track_popularity','track_name'],ascending=[0,1])
# Out:
#             track_name  track_popularity  percentage
# 15274           Poison                22    0.067016
# 2653           Breathe                21    0.063970
# 739              Alive                20    0.060924
# 6710           Forever                20    0.060924
# 14835         Paradise                19    0.057877
# ...                ...               ...         ...
# 23444     숙녀 (淑女) Lady                 1    0.003046
# 23445               쉼표                 1    0.003046
# 23446      중독 Overdose                 1    0.003046
# 23447   피카부 Peek-A-Boo                 1    0.003046
# 23448  하드캐리 Hard Carry                 1    0.003046
#
# [23449 rows x 3 columns]

# %%
song_grouped['track_name'][20000]
# Out:
# 'Think Twice'

# %%
song_grouped.tail(100)
# Out:
#                  track_name  track_popularity  percentage
# 23349              Папиросы                 1    0.003046
# 23350             Пацанская                 2    0.006092
# 23351  Пацаны с моего двора                 1    0.003046
# 23352             Пидарасия                 1    0.003046
# 23353                 Пламя                 1    0.003046
# ...                     ...               ...         ...
# 23444          숙녀 (淑女) Lady                 1    0.003046
# 23445                    쉼표                 1    0.003046
# 23446           중독 Overdose                 1    0.003046
# 23447        피카부 Peek-A-Boo                 1    0.003046
# 23448       하드캐리 Hard Carry                 1    0.003046
#
# [100 rows x 3 columns]

# %%
#new_music_df.tail(23)

# %%
new_music_df.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity  year  \
# 0        Ed Sheeran                66  2019
# 1          Maroon 5                67  2019
# 2      Zara Larsson                70  2019
# 3  The Chainsmokers                60  2019
# 4     Lewis Capaldi                69  2019
#
#                                     track_album_name playlist_name  \
# 0  I Don't Care (with Justin Bieber) [Loud Luxury...     Pop Remix
# 1                    Memories (Dillon Francis Remix)     Pop Remix
# ...

# %%
new_music_df = new_music_df.iloc[:20000,:]

# %%
new_music_df.shape
# Out:
# (20000, 9)

# %%
new_music_df['song_df'] = new_music_df['track_album_name'].astype(str)+" "+new_music_df['track_artist'].astype(str)+" "+new_music_df['playlist_name'].astype(str)+" "+new_music_df['playlist_subgenre'].astype(str)
# Out:
# <ipython-input-47-31a24dbd70fa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_music_df['song_df'] = new_music_df['track_album_name'].astype(str)+" "+new_music_df['track_artist'].astype(str)+" "+new_music_df['playlist_name'].astype(str)+" "+new_music_df['playlist_subgenre'].astype(str)

# %% [markdown]
# # Remove Punctuation

# %%
def remove_punctuation(text):
  import string
  translator = str.maketrans('','',string.punctuation)
  return text.translate(translator)

# %%
new_music_df['song_df'] = new_music_df['song_df'].apply(remove_punctuation)
# Out:
# <ipython-input-49-35700ac20c33>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_music_df['song_df'] = new_music_df['song_df'].apply(remove_punctuation)

# %%
new_music_df['song_df'].head()
# Out:
# 0    I Dont Care with Justin Bieber Loud Luxury Rem...
# 1    Memories Dillon Francis Remix Maroon 5 Pop Rem...
# 2    All the Time Don Diablo Remix Zara Larsson Pop...
# 3    Call You Mine  The Remixes The Chainsmokers Po...
# 4    Someone You Loved Future Humans Remix Lewis Ca...
# Name: song_df, dtype: object

# %%
new_music_df['track_name'][20000]
# Out:
# 'Tres Delinquentes - Radio'

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
sw = stopwords.words('english')
np.array(sw)
# Out:
# array(['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you',
#        "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself',
#        'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her',
#        'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them',
#        'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom',
#        'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are',
#        'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had',
#        'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and',
#        'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at',
#        'by', 'for', 'with', 'about', 'against', 'between', 'into',
#        'through', 'during', 'before', 'after', 'above', 'below', 'to',
#        'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under',
#        'again', 'further', 'then', 'once', 'here', 'there', 'when',
# ...

# %%
#def remove_stopwords(text):
  #'''a function of removing stopwords'''
  #text = [word.lower() for word in text.split() if word.lower() not in sw]
  #return" ".join(text)

# %%
#new_music_df['song_df'] = new_music_df['song_df'].apply(remove_stopwords)

# %%
new_music_df['song_df'] = new_music_df['song_df'].apply(lambda x:x.lower())
# Out:
# <ipython-input-53-b36c419f4c0f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_music_df['song_df'] = new_music_df['song_df'].apply(lambda x:x.lower())

# %%
new_music_df.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity  year  \
# 0        Ed Sheeran                66  2019
# 1          Maroon 5                67  2019
# 2      Zara Larsson                70  2019
# 3  The Chainsmokers                60  2019
# 4     Lewis Capaldi                69  2019
#
#                                     track_album_name playlist_name  \
# 0  I Don't Care (with Justin Bieber) [Loud Luxury...     Pop Remix
# 1                    Memories (Dillon Francis Remix)     Pop Remix
# ...

# %%
from nltk.stem.porter import PorterStemmer

# %%
pr = PorterStemmer()

# %%
def stem(text):
  y=[]
  for i in text.split():
    y.append(pr.stem(i))
  return" ".join(y)

# %%
new_music_df['song_df'] = new_music_df['song_df'].apply(stem)
# Out:
# <ipython-input-58-925ec374eeb5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_music_df['song_df'] = new_music_df['song_df'].apply(stem)

# %%
new_music_df['song_df']
# Out:
# 0        i dont care with justin bieber loud luxuri rem...
# 1        memori dillon franci remix maroon 5 pop remix ...
# 2        all the time don diablo remix zara larsson pop...
# 3        call you mine the remix the chainsmok pop remi...
# 4        someon you love futur human remix lewi capaldi...
#                                ...
# 20000    hip hop 100 hit urban rap r n b anthem inc jay...
# 20001    hispan caus panic kid frost chicano rap latin ...
# 20002    a warstori book ii the psycho realm chicano ra...
# 20003    the psycho realm the psycho realm chicano rap ...
# 20004         mexican invas tdre chicano rap latin hip hop
# Name: song_df, Length: 20000, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer(sublinear_tf= True, min_df=10, norm='l2', ngram_range=(1, 2), stop_words='english')
X_vc = vectorizer.fit_transform(new_music_df['song_df']).toarray()

#pd.DataFrame(X_vc.toarray()

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
cosine_similarity(X_vc)
# Out:
# array([[1.        , 0.33960359, 0.28601653, ..., 0.        , 0.        ,
#         0.        ],
#        [0.33960359, 1.        , 0.42857952, ..., 0.        , 0.        ,
#         0.        ],
#        [0.28601653, 0.42857952, 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.        , ..., 1.        , 0.92538772,
#         0.80377817],
#        [0.        , 0.        , 0.        , ..., 0.92538772, 1.        ,
#         0.72816738],
#        [0.        , 0.        , 0.        , ..., 0.80377817, 0.72816738,
#         1.        ]])

# %%
similarity = cosine_similarity(X_vc)

# %%
similarity.shape
# Out:
# (20000, 20000)

# %%
def recommend(music):
  music_index = new_music_df[new_music_df['song_df']=='track_name'].index[0]
  distances = similarity[music_index]
  music_list = sorted(list(enumerate(distances)),reverse=True,key=lambda x:x[1])[1:6]

  for i in music_list:
    print(new_music_df.iloc[i[0]].title)
