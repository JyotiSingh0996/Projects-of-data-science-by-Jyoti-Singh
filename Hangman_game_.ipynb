# %% [markdown]
# <a href="https://colab.research.google.com/github/JyotiSingh0996/Projects-of-data-science-by-Jyoti-Singh/blob/main/Hangman_game_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import requests
import random
import string
import secrets
import time
import re
import collections

try:
    from urllib.parse import parse_qs, urlencode, urlparse
except ImportError:
    from urlparse import parse_qs, urlparse
    from urllib import urlencode

from requests.packages.urllib3.exceptions import InsecureRequestWarning

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

# %%
import numpy as np
import itertools
from collections import defaultdict
from tqdm import tqdm

clip_max = 10000

def change_char(s, p, r):
	return s[:p]+r+s[p+1:]

def num_chars(word, char):
	n = 0
	for letter in word:
		if letter == char:
			n+=1

	return n

class HangmanAPI:
	def __init__(self, dict_path = '/content/words_250000_train.txt', max_freq_letters=5, max_reps = 3, access_token=None, timeout=None, session=None):
		text_file = open(dict_path,"r")
		self.full_dictionary = text_file.read().splitlines()
		text_file.close()
		self.n = len(self.full_dictionary)
		self.max_freq_letters = max_freq_letters
		self.max_reps = max_reps
		self.access_token = access_token
		self.timeout = timeout
		self.session = session



		new_dictionary = []
		for dict_word in self.full_dictionary:
			new_dictionary.append(''.join(set(dict_word)))

		current_dictionary_concat = ''.join(new_dictionary)

		c = collections.Counter(current_dictionary_concat)

		sorted_letter_count = c.most_common()

		self.most_freq_letters = [letter for letter, count in sorted_letter_count]

		# Hyperparameters:

		# self.weight_2 = 0.36
		# self.weight_3 = 0.14
		# self.weight_4 = 0.14
		# self.weight_5 = 0.36

		self.weight_2 = 0.08
		self.weight_3 = 0.42
		self.weight_4 = 0.25
		self.weight_5 = 0.25

		self.train()


	def start_game(self):
		mystery_index = np.random.randint(0, self.n)

		self.mystery_word = self.full_dictionary[mystery_index]

		# self.mystery_word = 'aarau'
		# self.mystery_word = 'tirunelveli'
		# self.mystery_word = 'abdominohysterectomy'
		# self.mystery_word = 'petitmaitre'

		# print('Mystery word is ' + self.mystery_word)

		self.guessed_letters = []

		a =  ord('a')

		self.unguessed_letters = [chr(i) for i in range(a,a+26)]

		self.word_len = len(self.mystery_word)

		self.current_clue = '_'*self.word_len

		self.current_dictionary = []
		for dict_word in self.full_dictionary:
			if len(dict_word) != self.word_len:
				continue
			self.current_dictionary.append(dict_word)

	def guess_v1(self):

		new_dictionary = []
		for dict_word in self.current_dictionary:
			if re.match(self.current_clue.replace("_","."), dict_word):
				new_dictionary.append(dict_word)

		self.current_dictionary = new_dictionary

		empty_chars = []
		i = 0
		for chars in self.current_clue:
			if chars == '_':
				empty_chars.append(i)
			i+=1

		new_dictionary = []
		for dict_word in self.current_dictionary:
			new_dictionary.append(''.join(set(dict_word)))

		current_dictionary_concat = ''.join(new_dictionary)

		c = collections.Counter(current_dictionary_concat)

		sorted_letter_count = c.most_common()

		num_letters = 0
		freq_chars = []
		for letter, count in sorted_letter_count:
			if letter in self.unguessed_letters:
				freq_chars.append(letter)
				num_letters += 1
				if(num_letters >= self.max_freq_letters):
					break

		IG = np.zeros(len(freq_chars))
		i = 0
		for char in freq_chars:
			# Consider every permutation of replacing '_' with char
			for num_reps in range(1, min(len(empty_chars)+1, self.max_reps)):
				for locs in itertools.combinations(empty_chars, num_reps):
					potential_word = self.current_clue
					for loc in locs:
						potential_word = change_char(potential_word, loc, char)

					new_dictionary = []
					for dict_word in self.current_dictionary:
						if re.match(potential_word.replace("_","."), dict_word):
							new_dictionary.append(dict_word)

					prob_case = len(new_dictionary)/len(self.current_dictionary)

					if prob_case !=0:
						IG[i] -= prob_case*np.log(prob_case)

			potential_word = self.current_clue

			new_dictionary = []
			for dict_word in self.current_dictionary:
				if char not in dict_word:
					new_dictionary.append(dict_word)

			prob_fail = len(new_dictionary)/len(self.current_dictionary)

			if prob_fail!=0:
				IG[i]/=prob_fail
			else:
				IG[i] = clip_max
			i+=1

		guess_index = np.argmax(IG)
		guess_char = freq_chars[guess_index]

		self.unguessed_letters.remove(guess_char)

		return guess_char


	def guess_v2(self):

		new_dictionary = []
		for dict_word in self.current_dictionary:
			if re.match(self.current_clue.replace("_","."), dict_word):
				new_dictionary.append(dict_word)

		self.current_dictionary = new_dictionary

		empty_chars = []
		i = 0
		for chars in self.current_clue:
			if chars == '_':
				empty_chars.append(i)
			i+=1

		new_dictionary = []
		for dict_word in self.current_dictionary:
			new_dictionary.append(''.join(set(dict_word)))

		current_dictionary_concat = ''.join(new_dictionary)

		c = collections.Counter(current_dictionary_concat)

		sorted_letter_count = c.most_common()

		num_letters = 0
		freq_chars = []
		for letter, count in sorted_letter_count:
			if letter in self.unguessed_letters:
				freq_chars.append(letter)
				num_letters += 1
				if(num_letters >= self.max_freq_letters):
					break

		print(freq_chars)

		IG = np.zeros(len(freq_chars))
		i = 0
		for char in freq_chars:
			# Consider every permutation of replacing '_' with char
			for num_reps in range(1, min(len(empty_chars)+1, self.max_reps)):
				for locs in itertools.combinations(empty_chars, num_reps):
					potential_word = self.current_clue
					for loc in locs:
						potential_word = change_char(potential_word, loc, char)

					new_dictionary = []
					for dict_word in self.current_dictionary:
						if re.match(potential_word.replace("_","."), dict_word) and num_chars(dict_word, char) == num_reps:
							new_dictionary.append(dict_word)

					prob_case = len(new_dictionary)/len(self.current_dictionary)

					if prob_case !=0:
						IG[i] -= prob_case*np.log(prob_case)

			potential_word = self.current_clue

			new_dictionary = []
			for dict_word in self.current_dictionary:
				if char not in dict_word:
					new_dictionary.append(dict_word)

			prob_fail = len(new_dictionary)/len(self.current_dictionary)

			if prob_fail!=0:
				IG[i]/=prob_fail
			else:
				IG[i] = clip_max
			i+=1

		guess_index = np.argmax(IG)
		guess_char = freq_chars[guess_index]

		self.unguessed_letters.remove(guess_char)

		return guess_char


	def train(self):
		print('Training starts.')
		model5 = defaultdict(lambda : defaultdict(lambda : defaultdict (lambda : defaultdict(lambda : defaultdict(int)))))
		model4 = defaultdict(lambda : defaultdict (lambda : defaultdict(lambda : defaultdict(int))))
		model3 = defaultdict(lambda : defaultdict(lambda : defaultdict(int)))
		model2 = defaultdict(lambda : defaultdict(lambda : defaultdict(int)))
		model1 = defaultdict(lambda : defaultdict(int))
		for word in self.full_dictionary:
			try:
				model2[len(word)][word[0]][word[1]]+=1
			except:
				continue
			model1[len(word)][word[0]]+=1
			for i in range(1,len(word)-3) :
				try :
					model3[word[i-1]][word[i]][word[i+1]]+=1
					model2[len(word)][word[i]][word[i+1]]+=1
					model1[len(word)][word[i]]+=1
					model4[word[i-1]][word[i]][word[i+1]][word[i+2]]+=1
					model5[word[i-1]][word[i]][word[i+1]][word[i+2]][word[i+3]]+=1
				except :
					continue
			try:
				i=len(word)-3
				model1[len(word)][word[i]]+=1
				model1[len(word)][word[i+1]]+=1
				model1[len(word)][word[i+2]]+=1
				model2[len(word)][word[i]][word[i+1]]+=1
				model2[len(word)][word[i+1]][word[i+2]]+=1
				model3[word[i-1]][word[i]][word[i+1]]+=1
				model3[word[i]][word[i+1]][word[i+2]]+=1
				model4[word[i-1]][word[i]][word[i+1]][word[i+2]]+=1
			except:
				continue

		self.model1 = model1
		self.model2 = model2
		self.model3 = model3
		self.model4 = model4
		self.model5 = model5

		print('Training Complete.')

	def unigram(self):
		max_prob = 0
		guess_char = ''
		for char in self.unguessed_letters:
			if self.model1[len(self.current_clue)][char] > max_prob:
				max_prob = self.model1[len(self.current_clue)][char]
				guess_char = char
		if guess_char != '':
			return guess_char
		else:
			for char in self.most_freq_letters:
				if char in self.unguessed_letters:
					return char


	def bigram(self, prior):
		assert len(prior) == len(self.unguessed_letters)
		posterior = np.zeros(len(self.unguessed_letters))

		first_empty = []
		second_empty = []

		for i in range(1,len(self.current_clue)):
			if self.current_clue[i-1] == '_' and self.current_clue[i] != '_':
				first_empty.append(i)

		for i in range(len(self.current_clue)-1):
			if self.current_clue[i+1] == '_' and self.current_clue[i] != '_':
				second_empty.append(i)

		for i in first_empty:
			letter = self.current_clue[i]
			count = 0

			for char in self.unguessed_letters:
				count+=self.model2[len(self.current_clue)][char][letter]

			if count == 0:
				count = 1

			for i, char in enumerate(self.unguessed_letters):
				posterior[i] += self.model2[len(self.current_clue)][char][letter]/count

		for i in second_empty:
			letter = self.current_clue[i]
			count = 0

			for char in self.unguessed_letters:
				count+=self.model2[len(self.current_clue)][letter][char]

			if count == 0:
				count = 1

			for i, char in enumerate(self.unguessed_letters):
				posterior[i] += self.model2[len(self.current_clue)][letter][char]/count


		posterior = posterior*self.weight_2 + prior

		max_prob = 0
		guess_char = ''
		for i, char in enumerate(self.unguessed_letters):
			if posterior[i]>max_prob:
				max_prob = posterior[i]
				guess_char = char

		if max_prob>0:
			return guess_char
		else:
			return self.unigram()

	def trigram(self, prior):
		assert len(prior) == len(self.unguessed_letters)
		posterior = np.zeros(len(self.unguessed_letters))

		first_empty = []
		second_empty = []
		third_empty = []

		for i in range(2,len(self.current_clue)):
			if self.current_clue[i-2] == '_' and self.current_clue[i-1] != '_' and self.current_clue[i] != '_':
				first_empty.append(i)

		for i in range(1,len(self.current_clue)-1):
			if self.current_clue[i-1] != '_' and self.current_clue[i] == '_' and self.current_clue[i+1] != '_':
				second_empty.append(i)

		for i in range(len(self.current_clue)-2):
			if self.current_clue[i] != '_' and self.current_clue[i+1] != '_' and self.current_clue[i+2] == '_':
				third_empty.append(i)


		for i in first_empty:
			second_letter = self.current_clue[i-1]
			third_letter = self.current_clue[i]

			count = 0
			for char in self.unguessed_letters:
				count+=self.model3[char][second_letter][third_letter]

			if count == 0:
				count = 1

			for i, char in enumerate(self.unguessed_letters):
				posterior[i] += self.model3[char][second_letter][third_letter]/count

		for i in second_empty:
			first_letter = self.current_clue[i-1]
			third_letter = self.current_clue[i+1]

			count = 0
			for char in self.unguessed_letters:
				count+=self.model3[first_letter][char][third_letter]

			if count == 0:
				count = 1

			for i, char in enumerate(self.unguessed_letters):
				posterior[i] += self.model3[first_letter][char][third_letter]/count

		for i in third_empty:
			first_letter = self.current_clue[i]
			second_letter = self.current_clue[i+1]

			count = 0
			for char in self.unguessed_letters:
				count+=self.model3[first_letter][second_letter][char]

			if count == 0:
				count = 1

			for i, char in enumerate(self.unguessed_letters):
				posterior[i] += self.model3[first_letter][second_letter][char]/count

		posterior = posterior*self.weight_3 + prior

		return self.bigram(posterior)


	def fourgram(self, prior):
		assert len(prior) == len(self.unguessed_letters)
		posterior = np.zeros(len(self.unguessed_letters))

		first_empty = []
		second_empty = []
		third_empty = []
		fourth_empty = []

		for i in range(3,len(self.current_clue)):
			if self.current_clue[i-3] == '_' and self.current_clue[i-2] != '_' and self.current_clue[i-1] != '_' and self.current_clue[i] != '_':
				first_empty.append(i)

		for i in range(2,len(self.current_clue)-1):
			if self.current_clue[i-2] != '_' and self.current_clue[i-1] == '_' and self.current_clue[i] != '_' and self.current_clue[i+1] != '_':
				second_empty.append(i)

		for i in range(1,len(self.current_clue)-2):
			if self.current_clue[i-1] != '_' and self.current_clue[i] != '_' and self.current_clue[i+1] == '_' and self.current_clue[i+2] != '_':
				third_empty.append(i)

		for i in range(len(self.current_clue)-3):
			if self.current_clue[i-2] != '_' and self.current_clue[i-1] != '_' and self.current_clue[i] != '_' and self.current_clue[i+1] == '_':
				fourth_empty.append(i)

		for i in first_empty:
			second_letter = self.current_clue[i-2]
			third_letter = self.current_clue[i-1]
			fourth_letter = self.current_clue[i]

			count = 0
			for first_letter in self.unguessed_letters:
				count+=self.model4[first_letter][second_letter][third_letter][fourth_letter]

			if count == 0:
				count = 1

			for i, first_letter in enumerate(self.unguessed_letters):
				posterior[i] += self.model4[first_letter][second_letter][third_letter][fourth_letter]/count

		for i in second_empty:
			first_letter = self.current_clue[i-2]
			third_letter = self.current_clue[i]
			fourth_letter = self.current_clue[i+1]

			count = 0
			for second_letter in self.unguessed_letters:
				count+=self.model4[first_letter][second_letter][third_letter][fourth_letter]

			if count == 0:
				count = 1

			for i, second_letter in enumerate(self.unguessed_letters):
				posterior[i] += self.model4[first_letter][second_letter][third_letter][fourth_letter]/count

		for i in third_empty:
			first_letter = self.current_clue[i-1]
			second_letter = self.current_clue[i]
			fourth_letter = self.current_clue[i+2]

			count = 0
			for third_letter in self.unguessed_letters:
				count+=self.model4[first_letter][second_letter][third_letter][fourth_letter]

			if count == 0:
				count = 1

			for i, third_letter in enumerate(self.unguessed_letters):
				posterior[i] += self.model4[first_letter][second_letter][third_letter][fourth_letter]/count

		for i in fourth_empty:
			first_letter = self.current_clue[i-2]
			second_letter = self.current_clue[i-1]
			third_letter = self.current_clue[i]

			count = 0
			for fourth_letter in self.unguessed_letters:
				count+=self.model4[first_letter][second_letter][third_letter][fourth_letter]

			if count == 0:
				count = 1

			for i, fourth_letter in enumerate(self.unguessed_letters):
				posterior[i] += self.model4[first_letter][second_letter][third_letter][fourth_letter]/count

		posterior = posterior*self.weight_4 + prior

		return self.trigram(posterior)


	def fivegram(self):
		posterior = np.zeros(len(self.unguessed_letters))

		first_empty = []
		second_empty = []
		third_empty = []
		fourth_empty = []
		fifth_empty = []

		for i in range(4,len(self.current_clue)):
			if self.current_clue[i-4] == '_' and self.current_clue[i-3] != '_' and self.current_clue[i-2] != '_' and self.current_clue[i-1] != '_' and self.current_clue[i] != '_':
				first_empty.append(i)

		for i in range(3,len(self.current_clue)-1):
			if self.current_clue[i-3] != '_' and self.current_clue[i-2] == '_' and self.current_clue[i-1] != '_' and self.current_clue[i] != '_' and self.current_clue[i+1] != '_':
				second_empty.append(i)

		for i in range(2,len(self.current_clue)-2):
			if self.current_clue[i-2] != '_' and self.current_clue[i-1] != '_' and self.current_clue[i] == '_' and self.current_clue[i+1] != '_' and self.current_clue[i+2] != '_':
				third_empty.append(i)

		for i in range(1,len(self.current_clue)-3):
			if self.current_clue[i-1] != '_' and self.current_clue[i] != '_' and self.current_clue[i+1] != '_' and self.current_clue[i+2] == '_' and self.current_clue[i+3] != '_':
				fourth_empty.append(i)

		for i in range(len(self.current_clue)-4):
			if self.current_clue[i] != '_' and self.current_clue[i+1] != '_' and self.current_clue[i+2] != '_' and self.current_clue[i+3] != '_' and self.current_clue[i+4] == '_':
				fifth_empty.append(i)

		for i in first_empty:
			second_letter = self.current_clue[i-3]
			third_letter = self.current_clue[i-2]
			fourth_letter = self.current_clue[i-1]
			fifth_letter = self.current_clue[i]

			count = 0
			for first_letter in self.unguessed_letters:
				count+=self.model5[first_letter][second_letter][third_letter][fourth_letter][fifth_letter]

			if count == 0:
				count = 1

			for i, first_letter in enumerate(self.unguessed_letters):
				posterior[i] += self.model5[first_letter][second_letter][third_letter][fourth_letter][fifth_letter]/count

		for i in second_empty:
			first_letter = self.current_clue[i-3]
			third_letter = self.current_clue[i-1]
			fourth_letter = self.current_clue[i]
			fifth_letter = self.current_clue[i+1]

			count = 0
			for second_letter in self.unguessed_letters:
				count+=self.model5[first_letter][second_letter][third_letter][fourth_letter][fifth_letter]

			if count == 0:
				count = 1

			for i, second_letter in enumerate(self.unguessed_letters):
				posterior[i] += self.model5[first_letter][second_letter][third_letter][fourth_letter][fifth_letter]/count

		for i in third_empty:
			first_letter = self.current_clue[i-2]
			second_letter = self.current_clue[i-1]
			fourth_letter = self.current_clue[i+1]
			fifth_letter = self.current_clue[i+2]

			count = 0
			for third_letter in self.unguessed_letters:
				count+=self.model5[first_letter][second_letter][third_letter][fourth_letter][fifth_letter]

			if count == 0:
				count = 1

			for i, third_letter in enumerate(self.unguessed_letters):
				posterior[i] += self.model5[first_letter][second_letter][third_letter][fourth_letter][fifth_letter]/count

		for i in fourth_empty:
			first_letter = self.current_clue[i-1]
			second_letter = self.current_clue[i]
			third_letter = self.current_clue[i+1]
			fifth_letter = self.current_clue[i+3]

			count = 0
			for fourth_letter in self.unguessed_letters:
				count+=self.model5[first_letter][second_letter][third_letter][fourth_letter][fifth_letter]

			if count == 0:
				count = 1

			for i, fourth_letter in enumerate(self.unguessed_letters):
				posterior[i] += self.model5[first_letter][second_letter][third_letter][fourth_letter][fifth_letter]/count

		for i in fifth_empty:
			first_letter = self.current_clue[i]
			second_letter = self.current_clue[i+1]
			third_letter = self.current_clue[i+2]
			fourth_letter = self.current_clue[i+3]

			count = 0
			for fifth_letter in self.unguessed_letters:
				count+=self.model5[first_letter][second_letter][third_letter][fourth_letter][fifth_letter]

			if count == 0:
				count = 1

			for i, fifth_letter in enumerate(self.unguessed_letters):
				posterior[i] += self.model5[first_letter][second_letter][third_letter][fourth_letter][fifth_letter]/count

		posterior = posterior*self.weight_5

		return self.fourgram(posterior)


	def guess_ngram(self):

		guess_char = self.fivegram()
		self.unguessed_letters.remove(guess_char)
		return guess_char

	def step(self, guess):
		if guess in self.mystery_word:
			indices = []
			for i in range(len(self.mystery_word)):
				if  self.mystery_word[i] == guess:
					indices.append(i)

			for i in indices:
				self.current_clue = change_char(self.current_clue, i, guess)

			return 0

		else:
			return -1

	def tune_hyperparameters(self, batch_size, num_batches, T0, delta0):
		performance = 0.0
		T = T0
		delta = delta0
		for batch in range(num_batches):
			N_success = 0.0
			for count in range(batch_size):
				hangman_agent.start_game()
				N_left = N_strikes
				while N_left>0:
					# guess = hangman_agent.guess()
					guess = hangman_agent.guess_ngram()
					N_left += hangman_agent.step(guess)
					if('_' in hangman_agent.current_clue):
						continue
					else:
						N_success += 1
						break

			DE = N_success - performance

			if N_success>performance:
				performance = N_success

			print(batch, self.weight_2, self.weight_3, self.weight_4, self.weight_5)

			print('Accuracy of the algorithm: ', str(N_success/batch_size * 100))

			p_sample = np.exp(-max(DE,0)/ T)

			if np.random.uniform(0,1)<p_sample:
				x = np.random.uniform(-delta, delta, 5)
				x[4] = 0
				x[0] = 0

				self.weight_2 += x[1] - x[0]
				self.weight_3 += x[2] - x[1]
				self.weight_4 += x[3] - x[2]
				self.weight_5 += x[4] - x[3]

			T/=1.1
			delta/=1.05




dict_path = '/content/words_250000_train.txt'

N_strikes = 6
N_samples = 100

N_success = 0.0

hangman_agent = HangmanAPI(dict_path)

hangman_agent.tune_hyperparameters(100, 100, 100, 0.2)

# 0.03864019512995809 0.15428121558276808 0.12841833151811646 0.6786602577691578

for count in range(N_samples):
	a = time.time()
	print(count)
	hangman_agent.start_game()
	N_left = N_strikes
	while N_left>0:
		# guess = hangman_agent.guess()
		guess = hangman_agent.guess_ngram()
		print('current clue: ' + hangman_agent.current_clue)
		N_left += hangman_agent.step(guess)
		print('guess letter: ' + guess)
		if('_' in hangman_agent.current_clue):
			continue
		else:
			print('Sucess! The mystery word was: ' + hangman_agent.mystery_word)
			print('Number of strikes used: ' + str(N_strikes - N_left))
			N_success += 1
			break

	print('Done in ' + str(time.time()-a) + ' seconds')

print('Accuracy of the algorithm: ', str(N_success/N_samples * 100))
# Out:
# Training starts.
# Training Complete.
# 0 0.08 0.42 0.25 0.25
# Accuracy of the algorithm:  46.0
# 1 0.012104358351264707 0.3151022881792681 0.569203190251356 0.10359016321811115
# Accuracy of the algorithm:  37.0
# 2 -0.11422186936473717 0.5893302472471319 0.2760841511735271 0.24880747094407818
# Accuracy of the algorithm:  56.99999999999999
# 3 -0.13199679163302985 0.5413751379422379 0.280959750246937 0.30966190344385497
# Accuracy of the algorithm:  50.0
# 4 -0.2065012528912668 0.5974848663118988 0.25364472049084574 0.3553716660885222
# Accuracy of the algorithm:  46.0
# 5 -0.09591150125452394 0.4292127084572853 0.403278937751815 0.26341985504542353
# Accuracy of the algorithm:  61.0
# 6 -0.037578771473101485 0.34682855733991075 0.3506688901378954 0.3400813239952953
# Accuracy of the algorithm:  51.0
# 7 -0.006178013886408984 0.19053302887839882 0.5933691225483553 0.22227586245965475
# Accuracy of the algorithm:  48.0
# 8 -0.02346269027819088 0.2386583224782416 0.6659686636674924 0.11883570413245678
# Accuracy of the algorithm:  45.0
# 9 0.025380365867699164 0.1797256070862343 0.7891158540319788 0.0057781730140876175
# Accuracy of the algorithm:  44.0
# 10 -0.018786761265258287 0.2990071846230542 0.7704814839640237 -0.050701907321819784
# Accuracy of the algorithm:  38.0
# 11 0.06617770480500988 0.21282781553503666 0.7778322351039804 -0.056837755444027
# Accuracy of the algorithm:  45.0
# 12 0.15202777176792853 0.21820248288133737 0.7955134469293714 -0.16574370157863738
# Accuracy of the algorithm:  33.0
# 13 0.19530165719548348 0.22965482982648117 0.6458611624907407 -0.07081764951270529
# Accuracy of the algorithm:  37.0
# 14 0.13800864987349573 0.3215768820522189 0.6950822849767196 -0.1546678169024343
# Accuracy of the algorithm:  44.0
# 15 0.0595605663073437 0.3707545459185235 0.6322978643666163 -0.06261297659248352
# Accuracy of the algorithm:  55.00000000000001
# 16 0.03934234239881457 0.34507146374447023 0.6160375217584609 -0.00045132790174579746
# Accuracy of the algorithm:  41.0
# 17 0.0814973323423137 0.24920758877964336 0.6756552451512841 -0.006360166273241159
# Accuracy of the algorithm:  48.0
# 18 0.13711533912880142 0.2781866380980339 0.6760284769915933 -0.09133045421842864
# Accuracy of the algorithm:  43.0
# 19 0.0743641757326349 0.3334229973597952 0.6097986603464988 -0.017585833438928902
# Accuracy of the algorithm:  46.0
# 20 0.09900842426293356 0.24731491286396057 0.7024012521296891 -0.04872458925658325
# Accuracy of the algorithm:  45.0
# 21 0.11359659832584201 0.18610823741995006 0.7007014318532923 -0.00040626759908443666
# Accuracy of the algorithm:  43.0
# 22 0.16453851834227917 0.1833093650744948 0.6241969641311863 0.02795515245203955
# Accuracy of the algorithm:  39.0
# 23 0.17204199599712355 0.1116515333982646 0.6439724261004459 0.07233404450416572
# Accuracy of the algorithm:  49.0
# 24 0.10834018607799852 0.17051729335429314 0.5936037243407073 0.12753879622700087
# Accuracy of the algorithm:  47.0
# 25 0.0546761684985128 0.24976931593439627 0.6056280144742806 0.08992650109281017
# Accuracy of the algorithm:  50.0
# 26 0.016729380815088277 0.3317167823365429 0.5151266327418802 0.13642720410648845
# Accuracy of the algorithm:  45.0
# 27 0.0674566552538774 0.22824802456027665 0.5998516220513369 0.10444369813450888
# Accuracy of the algorithm:  40.0
# 28 0.07336366307853384 0.17908867720112542 0.6012583200213917 0.14628933969894892
# Accuracy of the algorithm:  52.0
# 29 0.08347142989427503 0.1800215952153173 0.5592165513251564 0.1772904235652512
# Accuracy of the algorithm:  56.00000000000001
# 30 0.08049824008692412 0.1985649507356981 0.519391472402592 0.20154533677478567
# Accuracy of the algorithm:  51.0
# 31 0.04028411331012571 0.23095579347657996 0.5566983011499922 0.17206179206330194
# Accuracy of the algorithm:  49.0
# 32 0.050174158920720045 0.19285960796297724 0.5710343809236219 0.18593185219268057
# Accuracy of the algorithm:  52.0
# 33 0.048021931787766564 0.18173896795451466 0.5642560927934522 0.2059830074642663
# Accuracy of the algorithm:  51.0
# 34 0.009209683280845468 0.21850193730602657 0.5839038586362626 0.18838452077686507
# Accuracy of the algorithm:  56.99999999999999
# 35 0.017433150873807444 0.24208191553433342 0.5218996582375913 0.21858527535426753
# Accuracy of the algorithm:  42.0
# 36 0.03275242568497879 0.2316614101761618 0.5441037532073977 0.19148241093146143
# Accuracy of the algorithm:  44.0
# 37 0.05103919528973682 0.23327777687638876 0.5271655678171276 0.1885174600167464
# Accuracy of the algorithm:  49.0
# 38 0.06360817326472454 0.23942840751246014 0.5310353475155051 0.1659280717073099
# Accuracy of the algorithm:  42.0
# 39 0.0814595830935542 0.24242877717765599 0.5036595046175366 0.17245213511125282
# Accuracy of the algorithm:  62.0
# 40 0.0814595830935542 0.24242877717765599 0.5036595046175366 0.17245213511125282
# Accuracy of the algorithm:  46.0
# 41 0.08675929336379753 0.23545885877799466 0.4805217810626186 0.1972600667955888
# Accuracy of the algorithm:  56.99999999999999
# 42 0.07811818989473522 0.218804873579763 0.49910250332503237 0.203974433200469
# Accuracy of the algorithm:  48.0
# 43 0.06386313007706423 0.20878730384249605 0.5362195702252001 0.1911299958552393
# Accuracy of the algorithm:  52.0
# 44 0.04526118171788992 0.2383078261454465 0.5050556099368169 0.2113753821998464
# Accuracy of the algorithm:  37.0
# 45 0.02241063118251012 0.23941651807719377 0.5215060758293526 0.2166667749109431
# Accuracy of the algorithm:  60.0
# 46 0.004974035279339033 0.2786478283099159 0.5064039140585725 0.20997422235217217
# Accuracy of the algorithm:  51.0
# 47 -0.004073921972301409 0.2987941534952925 0.4826863034436556 0.222593465033353
# Accuracy of the algorithm:  52.0
# 48 0.009568126767576552 0.3012598883574671 0.45525336515976883 0.23391861971518724
# Accuracy of the algorithm:  52.0
# 49 0.0016111762981169484 0.32397988762498103 0.4481348475094121 0.22627408856748957
# Accuracy of the algorithm:  48.0
# 50 0.019204243352022456 0.2897272394041125 0.452354114792392 0.2387144024514727
# Accuracy of the algorithm:  61.0
# 51 0.034395408323759064 0.2918883782372929 0.44749120245056484 0.22622501098838288
# Accuracy of the algorithm:  45.0
# 52 0.044287675371683155 0.28322221310763485 0.44435782358403286 0.22813228793664886
# Accuracy of the algorithm:  46.0
# 53 0.04604477834338823 0.28373219198219035 0.43612521196404497 0.23409781771037613
# Accuracy of the algorithm:  50.0
# 54 0.03989978184957598 0.28638960223926807 0.4286880614768391 0.24502255443431656
# Accuracy of the algorithm:  49.0
# 55 0.030620261097494043 0.2838679633352259 0.4516337399231329 0.23387803564414686
# Accuracy of the algorithm:  56.00000000000001
# 56 0.0422167274293634 0.2856768010230673 0.4404433319461308 0.23166313960143825
# Accuracy of the algorithm:  57.99999999999999
# 57 0.05139817720342655 0.284549143674086 0.4260286542588578 0.2380240248636294
# Accuracy of the algorithm:  50.0
# 58 0.04169246133344126 0.2861776058924161 0.4229050655282313 0.24922486724591109
# Accuracy of the algorithm:  56.99999999999999
# 59 0.05280552341709989 0.2809251442215728 0.4216657207978086 0.24460361156351845
# Accuracy of the algorithm:  53.0
# 60 0.051414631534942176 0.28555365501352237 0.41096720701567707 0.2520645064358581
# Accuracy of the algorithm:  54.0
# 61 0.04473386131137448 0.298177166098362 0.4047442631310834 0.2523447094591798
# Accuracy of the algorithm:  55.00000000000001
# 62 0.034714656477074494 0.3020134600072554 0.41877863324987835 0.24449325026579144
# Accuracy of the algorithm:  61.0
# 63 0.025491082326628105 0.313653285603378 0.41907263794080757 0.24178299412918597
# Accuracy of the algorithm:  54.0
# 64 0.02184864939287738 0.31749095069445454 0.4137905592988548 0.24686984061381295
# Accuracy of the algorithm:  53.0
# 65 0.024730198528481684 0.3160784950427158 0.42089203430439476 0.23829927212440744
# Accuracy of the algorithm:  57.99999999999999
# 66 0.027119889138982133 0.311431890184198 0.423149007044624 0.23829921363219558
# Accuracy of the algorithm:  55.00000000000001
# 67 0.023129273831764184 0.32177129762141354 0.42420165286609507 0.23089777568072686
# Accuracy of the algorithm:  52.0
# 68 0.0156312141717935 0.3307285030018467 0.42490012928091714 0.22874015354544233
# Accuracy of the algorithm:  51.0
# 69 0.010751413396979007 0.33194272940880193 0.4309341167828434 0.22637174041137534
# Accuracy of the algorithm:  54.0
# 70 0.003996410444982511 0.34306351646040295 0.4204516236772001 0.23248844941741412
# Accuracy of the algorithm:  52.0
# 71 0.0066876232237151395 0.34155844880105557 0.42336932882429135 0.2283845991509377
# Accuracy of the algorithm:  51.0
# 72 0.001384879085680719 0.34568200073107086 0.42209497157301595 0.2308381486102322
# Accuracy of the algorithm:  54.0
# 73 -0.0037783155024966354 0.3503799313801429 0.42471025368070575 0.2286881304416477
# Accuracy of the algorithm:  57.99999999999999
# 74 -0.007247859103031611 0.35865163791548427 0.4177661020896598 0.23083011909788725
# Accuracy of the algorithm:  47.0
# 75 -0.004623391292608575 0.35870819374828455 0.4196915612657692 0.2262236362785546
# Accuracy of the algorithm:  54.0
# 76 -0.0049898445905683176 0.3637389689315236 0.41396927231918723 0.22728160333985728
# Accuracy of the algorithm:  48.0
# 77 -0.003516296731757471 0.359783770089072 0.4133724773977946 0.23036004924489065
# Accuracy of the algorithm:  57.99999999999999
# 78 -0.007093383198145058 0.3639256119154354 0.41349401335156116 0.22967375793114825
# Accuracy of the algorithm:  53.0
# 79 -0.0030716405853027694 0.358937211339034 0.4176423760873342 0.22649205315893434
# Accuracy of the algorithm:  50.0
# 80 -6.87700855630741e-05 0.3549963708564025 0.41971909969521415 0.22535329953394617
# Accuracy of the algorithm:  53.0
# 81 0.0027717952665093915 0.35454054683349523 0.41808456408696826 0.22460309381302684
# Accuracy of the algorithm:  52.0
# 82 0.004649771240120056 0.35376833454230205 0.41970781892090164 0.22187407529667597
# Accuracy of the algorithm:  55.00000000000001
# 83 0.005493268189322682 0.3528922572466494 0.41755275918815526 0.22406171537587233
# Accuracy of the algorithm:  56.00000000000001
# 84 0.008405882894074073 0.3477252718988657 0.4174689709979646 0.2263998742090953
# Accuracy of the algorithm:  63.0
# 85 0.008405882894074073 0.3477252718988657 0.4174689709979646 0.2263998742090953
# Accuracy of the algorithm:  56.00000000000001
# 86 0.006583067286133134 0.35009529656232086 0.4199478156372116 0.22337382051433402
# Accuracy of the algorithm:  43.0
# 87 0.006747967378765287 0.3482963578169155 0.4188698428730518 0.22608583193126708
# Accuracy of the algorithm:  55.00000000000001
# 88 0.004772860553914127 0.35091922423564126 0.4204135709610893 0.22389434424935495
# Accuracy of the algorithm:  54.0
# 89 0.005198620048982272 0.3525936769917226 0.41561385194961287 0.22659385100968182
# Accuracy of the algorithm:  50.0
# 90 0.005723391641557124 0.3526286156386026 0.4163232429113629 0.22532474980847692
# Accuracy of the algorithm:  52.0
# 91 0.004670359915814888 0.35407871713532124 0.4143011365870884 0.226949786361775
# Accuracy of the algorithm:  53.0
# 92 0.002971124257880504 0.3549233599083558 0.4143254806550586 0.22778003517870463
# Accuracy of the algorithm:  47.0
# 93 0.0031036119575368667 0.35628395388136197 0.41206523915168025 0.22854719500942042
# Accuracy of the algorithm:  55.00000000000001
# 94 0.005047612982588539 0.3535398661814256 0.4145824010249732 0.22683011981101223
# Accuracy of the algorithm:  59.0
# 95 0.005915960941596915 0.35348024160204916 0.4145505429804209 0.22605325447593258
# Accuracy of the algorithm:  48.0
# 96 0.00402195451044707 0.3546616932945524 0.4156460273289616 0.2256703248660385
# Accuracy of the algorithm:  60.0
# 97 0.002176152316048251 0.35722744801296824 0.41501809681308177 0.22557830285790126
# Accuracy of the algorithm:  64.0
# 98 0.002176152316048251 0.35722744801296824 0.41501809681308177 0.22557830285790126
# Accuracy of the algorithm:  63.0
# 99 0.003553621421513664 0.3563581543957597 0.4137380341721461 0.22635019001058013
# Accuracy of the algorithm:  61.0
# 0
# current clue: ________
# guess letter: e
# current clue: __e_e___
# guess letter: n
# current clue: __e_e___
# guess letter: r
# current clue: __e_er__
# guess letter: t
# current clue: __e_er__
# guess letter: v
# current clue: __e_er__
# guess letter: l
# current clue: __e_er_l
# guess letter: a
# current clue: __e_er_l
# guess letter: o
# current clue: __e_erol
# guess letter: m
# current clue: __emerol
# guess letter: h
# current clue: _hemerol
# guess letter: c
# current clue: _hemerol
# guess letter: p
# Sucess! The mystery word was: phemerol
# Number of strikes used: 5
# Done in 0.05245709419250488 seconds
# 1
# current clue: ______________
# guess letter: e
# current clue: ___e____e_____
# guess letter: r
# current clue: ___er___e_____
# guess letter: t
# current clue: ___er__te____t
# guess letter: s
# current clue: s__er__te____t
# guess letter: a
# current clue: s__er__te__a_t
# guess letter: n
# current clue: s__er_nten_ant
# guess letter: i
# current clue: s__erinten_ant
# guess letter: d
# current clue: s__erintendant
# guess letter: p
# current clue: s_perintendant
# guess letter: u
# Sucess! The mystery word was: superintendant
# Number of strikes used: 0
# Done in 0.06082415580749512 seconds
# 2
# current clue: _________
# guess letter: e
# current clue: _______e_
# guess letter: r
# current clue: __r____e_
# guess letter: a
# current clue: __r____e_
# guess letter: o
# current clue: __r____e_
# guess letter: t
# current clue: __r____e_
# guess letter: i
# current clue: __r_i__e_
# guess letter: m
# current clue: __r_i__e_
# guess letter: d
# current clue: __r_i__e_
# guess letter: n
# Done in 0.04603743553161621 seconds
# 3
# current clue: _______
# guess letter: e
# current clue: _______
# guess letter: a
# current clue: ____a__
# guess letter: r
# current clue: ____ar_
# guess letter: i
# current clue: ____ar_
# guess letter: t
# current clue: ____ar_
# guess letter: c
# current clue: ____ar_
# guess letter: d
# current clue: ____ard
# guess letter: w
# current clue: ____ard
# guess letter: h
# Done in 0.041323184967041016 seconds
# 4
# current clue: ________
# guess letter: e
# current clue: ________
# guess letter: a
# current clue: ________
# guess letter: i
# current clue: ______i_
# guess letter: n
# current clue: ______i_
# guess letter: l
# current clue: __l___i_
# guess letter: o
# current clue: _ol__oi_
# guess letter: d
# current clue: _ol__oid
# guess letter: r
# current clue: _ol__oid
# guess letter: t
# current clue: _ol__oid
# guess letter: c
# Done in 0.03645181655883789 seconds
# 5
# current clue: ______________
# guess letter: e
# current clue: ____________e_
# guess letter: r
# current clue: ____________e_
# guess letter: n
# current clue: _____n_____ne_
# guess letter: s
# current clue: _____n_____ne_
# guess letter: i
# current clue: i____n_i_i_ne_
# guess letter: o
# current clue: i___on_i_ione_
# guess letter: t
# current clue: i___on_itione_
# guess letter: d
# current clue: i___onditioned
# guess letter: c
# current clue: i__conditioned
# guess letter: a
# current clue: i__conditioned
# guess letter: l
# Sucess! The mystery word was: illconditioned
# Number of strikes used: 3
# Done in 0.033768653869628906 seconds
# 6
# current clue: _________
# guess letter: e
# current clue: e____e___
# guess letter: r
# current clue: err__e___
# guess letter: i
# current clue: err__e___
# guess letter: a
# current clue: err__e___
# guess letter: o
# current clue: erro_eo__
# guess letter: g
# current clue: erro_eo__
# guess letter: n
# current clue: erroneo__
# guess letter: u
# current clue: erroneou_
# guess letter: s
# Sucess! The mystery word was: erroneous
# Number of strikes used: 3
# Done in 0.025371313095092773 seconds
# 7
# current clue: ____________
# guess letter: e
# current clue: _____e______
# guess letter: r
# current clue: _____e______
# guess letter: n
# current clue: _____e______
# guess letter: d
# current clue: _____e______
# guess letter: s
# current clue: _____e______
# guess letter: t
# current clue: _____e____t_
# guess letter: i
# current clue: _i___e___it_
# guess letter: l
# current clue: _i___el__it_
# guess letter: y
# current clue: _i___el__ity
# guess letter: c
# current clue: _i___el_city
# guess letter: a
# current clue: _i___el_city
# guess letter: o
# current clue: _i___elocity
# guess letter: v
# current clue: _i__velocity
# guess letter: u
# Done in 0.04264974594116211 seconds
# 8
# current clue: ___________
# guess letter: e
# current clue: _e____e_e__
# guess letter: n
# current clue: _e____e_en_
# guess letter: t
# current clue: _e___te_ent
# guess letter: m
# current clue: _e___tement
# guess letter: s
# current clue: _e___tement
# guess letter: a
# current clue: _e_a_tement
# guess letter: r
# current clue: _e_artement
# guess letter: p
# current clue: _epartement
# guess letter: d
# Sucess! The mystery word was: departement
# Number of strikes used: 1
# Done in 0.02803826332092285 seconds
# 9
# current clue: ____________
# guess letter: e
# current clue: _e__________
# guess letter: r
# current clue: re__________
# guess letter: s
# current clue: re______s___
# guess letter: d
# current clue: re______s___
# guess letter: a
# current clue: re___a__s___
# guess letter: c
# current clue: re___a__s___
# guess letter: t
# current clue: re__ta__s___
# guess letter: n
# current clue: re__ta__s_n_
# guess letter: i
# current clue: re_ita_isin_
# guess letter: l
# current clue: re_italisin_
# guess letter: g
# current clue: re_italising
# guess letter: m
# current clue: re_italising
# guess letter: p
# current clue: re_italising
# guess letter: v
# Sucess! The mystery word was: revitalising
# Number of strikes used: 4
# Done in 0.03309965133666992 seconds
# 10
# current clue: _________
# guess letter: e
# current clue: _____e___
# guess letter: r
# current clue: r____e___
# guess letter: s
# current clue: r__sse__s
# guess letter: a
# current clue: r__ssea_s
# guess letter: i
# current clue: r__ssea_s
# guess letter: u
# current clue: r_usseaus
# guess letter: o
# Sucess! The mystery word was: rousseaus
# Number of strikes used: 1
# Done in 0.041649818420410156 seconds
# 11
# current clue: __________
# guess letter: e
# current clue: __________
# guess letter: i
# current clue: _i_i_i_i__
# guess letter: t
# current clue: _i_i_i_i__
# guess letter: l
# current clue: _i_i_i_i__
# guess letter: n
# current clue: _ini_i_in_
# guess letter: s
# current clue: _ini_isin_
# guess letter: c
# current clue: _ini_isin_
# guess letter: m
# current clue: minimisin_
# guess letter: g
# Sucess! The mystery word was: minimising
# Number of strikes used: 4
# Done in 0.03261756896972656 seconds
# 12
# current clue: _____________
# guess letter: e
# current clue: _____e______e
# guess letter: r
# current clue: _r___er_____e
# guess letter: t
# current clue: _r_t_er_____e
# guess letter: h
# current clue: _r_ther_____e
# guess letter: o
# current clue: _rother_____e
# guess letter: p
# current clue: _rother_____e
# guess letter: i
# current clue: _rother__i__e
# guess letter: a
# current clue: _rother__i__e
# guess letter: m
# current clue: _rother__i__e
# guess letter: s
# current clue: _rothers_i__e
# guess letter: c
# current clue: crothers_i__e
# guess letter: v
# current clue: crothersvi__e
# guess letter: l
# Sucess! The mystery word was: crothersville
# Number of strikes used: 3
# Done in 0.02950596809387207 seconds
# 13
# current clue: ___________
# guess letter: e
# current clue: __________e
# guess letter: t
# current clue: __________e
# guess letter: r
# current clue: __r_______e
# guess letter: a
# current clue: __r____a__e
# guess letter: o
# current clue: _or____a__e
# guess letter: i
# current clue: _or_i__a__e
# guess letter: m
# current clue: _or_i__a__e
# guess letter: d
# current clue: _or_idda__e
# guess letter: b
# current clue: _orbiddab_e
# guess letter: l
# current clue: _orbiddable
# guess letter: s
# current clue: _orbiddable
# guess letter: f
# Sucess! The mystery word was: forbiddable
# Number of strikes used: 3
# Done in 0.03752946853637695 seconds
# 14
# current clue: ____________
# guess letter: e
# current clue: ____e_____e_
# guess letter: r
# current clue: ____e_r___e_
# guess letter: a
# current clue: ____e_r___e_
# guess letter: t
# current clue: t___etr__te_
# guess letter: i
# current clue: t_i_etr__te_
# guess letter: m
# current clue: t_i_etr__te_
# guess letter: n
# current clue: t_i_etr__te_
# guess letter: o
# current clue: t_i_etr__te_
# guess letter: y
# current clue: t_i_etr__te_
# guess letter: u
# current clue: t_i_etru_te_
# guess letter: s
# current clue: t_i_etruste_
# guess letter: d
# current clue: t_i_etrusted
# guess letter: h
# Done in 0.02578425407409668 seconds
# 15
# current clue: _______
# guess letter: e
# current clue: _______
# guess letter: a
# current clue: _a_____
# guess letter: r
# current clue: ra_____
# guess letter: t
# current clue: ra_____
# guess letter: n
# current clue: ra_____
# guess letter: c
# current clue: ra_____
# guess letter: p
# current clue: ra_____
# guess letter: l
# Done in 0.03961634635925293 seconds
# 16
# current clue: _______
# guess letter: e
# current clue: _______
# guess letter: a
# current clue: _______
# guess letter: i
# current clue: _____i_
# guess letter: n
# current clue: ____ni_
# guess letter: o
# current clue: ___oni_
# guess letter: c
# current clue: ___oni_
# guess letter: t
# current clue: ___oni_
# guess letter: s
# current clue: ___onis
# guess letter: m
# current clue: ___onis
# guess letter: r
# Done in 0.03703022003173828 seconds
# 17
# current clue: ______________
# guess letter: e
# current clue: _______e_e__e_
# guess letter: n
# current clue: _______e_en_e_
# guess letter: t
# current clue: _______e_en_e_
# guess letter: c
# current clue: _______e_en_e_
# guess letter: d
# current clue: _______e_ended
# guess letter: m
# current clue: m______e_ended
# guess letter: r
# current clue: m_____re_ended
# guess letter: p
# current clue: m___ppre_ended
# guess letter: a
# current clue: m__appre_ended
# guess letter: s
# current clue: m_sappre_ended
# guess letter: i
# current clue: misappre_ended
# guess letter: h
# Sucess! The mystery word was: misapprehended
# Number of strikes used: 2
# Done in 0.04369783401489258 seconds
# 18
# current clue: ______
# guess letter: e
# current clue: ______
# guess letter: a
# current clue: __a___
# guess letter: r
# current clue: __a___
# guess letter: n
# current clue: __an__
# guess letter: t
# current clue: __ant_
# guess letter: i
# current clue: __ant_
# guess letter: l
# current clue: _lant_
# guess letter: p
# current clue: _lant_
# guess letter: u
# current clue: _lant_
# guess letter: o
# Done in 0.024585723876953125 seconds
# 19
# current clue: ___________
# guess letter: e
# current clue: _______e___
# guess letter: r
# current clue: ___r___er__
# guess letter: t
# current clue: ___r__ter__
# guess letter: s
# current clue: ___r__ter__
# guess letter: n
# current clue: ___r__ter_n
# guess letter: i
# current clue: ___r__ter_n
# guess letter: a
# current clue: _a_r__teran
# guess letter: p
# current clue: _a_r_pteran
# guess letter: o
# current clue: _a_ropteran
# guess letter: c
# current clue: _acropteran
# guess letter: m
# Sucess! The mystery word was: macropteran
# Number of strikes used: 2
# Done in 0.03164339065551758 seconds
# 20
# current clue: ________
# guess letter: e
# current clue: ______e_
# guess letter: r
# current clue: ___r__e_
# guess letter: a
# current clue: ___r__ea
# guess letter: h
# current clue: h__r__ea
# guess letter: o
# current clue: h__ro_ea
# guess letter: p
# current clue: h__ro_ea
# guess letter: t
# current clue: h__ro_ea
# guess letter: l
# current clue: h__rolea
# guess letter: y
# current clue: hy_rolea
# guess letter: d
# Sucess! The mystery word was: hydrolea
# Number of strikes used: 2
# Done in 0.03243207931518555 seconds
# 21
# current clue: _____________
# guess letter: e
# current clue: _____________
# guess letter: i
# current clue: _________i___
# guess letter: t
# current clue: _________i___
# guess letter: n
# current clue: n_n______i___
# guess letter: o
# current clue: non____o_i___
# guess letter: s
# current clue: nons___o_i___
# guess letter: u
# current clue: nons___o_i___
# guess letter: p
# current clue: nons___o_i___
# guess letter: a
# current clue: nons___o_i_a_
# guess letter: c
# current clue: nons___o_ica_
# guess letter: l
# current clue: nons___olical
# guess letter: h
# current clue: nons___olical
# guess letter: y
# current clue: nonsy__olical
# guess letter: m
# current clue: nonsym_olical
# guess letter: b
# Sucess! The mystery word was: nonsymbolical
# Number of strikes used: 5
# Done in 0.03371572494506836 seconds
# 22
# current clue: ______________
# guess letter: e
# current clue: ___e__________
# guess letter: r
# current clue: ___e__________
# guess letter: n
# current clue: __ne__________
# guess letter: s
# current clue: s_ne__________
# guess letter: i
# current clue: s_ne______i___
# guess letter: o
# current clue: s_ne__o_o_i___
# guess letter: h
# current clue: s_ne_ho_o_i___
# guess letter: t
# current clue: s_ne_ho_o_i___
# guess letter: p
# current clue: s_ne_ho_o_i___
# guess letter: c
# current clue: s_necho_o_ic__
# guess letter: l
# current clue: s_necholo_ic_l
# guess letter: g
# current clue: s_nechologic_l
# guess letter: a
# current clue: s_nechological
# guess letter: y
# Sucess! The mystery word was: synechological
# Number of strikes used: 3
# Done in 0.03116631507873535 seconds
# 23
# current clue: ____
# guess letter: a
# current clue: a__a
# guess letter: r
# current clue: a__a
# guess letter: l
# current clue: al_a
# guess letter: i
# current clue: al_a
# guess letter: e
# current clue: al_a
# guess letter: m
# current clue: al_a
# guess letter: v
# Sucess! The mystery word was: alva
# Number of strikes used: 4
# Done in 0.03734946250915527 seconds
# 24
# current clue: __________
# guess letter: e
# current clue: _e________
# guess letter: r
# current clue: _e_______r
# guess letter: t
# current clue: _e___t___r
# guess letter: a
# current clue: _e_a_t__ar
# guess letter: n
# current clue: _e_a_t__ar
# guess letter: s
# current clue: _e_ast__ar
# guess letter: l
# current clue: _e_ast_lar
# guess letter: u
# current clue: _e_ast_lar
# guess letter: i
# current clue: _e_ast_lar
# guess letter: o
# current clue: _e_ast_lar
# guess letter: y
# current clue: _e_astylar
# guess letter: m
# current clue: _e_astylar
# guess letter: c
# current clue: _ecastylar
# guess letter: d
# Sucess! The mystery word was: decastylar
# Number of strikes used: 5
# Done in 0.036103010177612305 seconds
# 25
# current clue: _______
# guess letter: e
# current clue: ______e
# guess letter: l
# current clue: l_____e
# guess letter: i
# current clue: l___i_e
# guess letter: n
# current clue: l___i_e
# guess letter: v
# current clue: l___i_e
# guess letter: t
# current clue: l_t_i_e
# guess letter: a
# current clue: lat_i_e
# guess letter: r
# current clue: latri_e
# guess letter: c
# Sucess! The mystery word was: latrice
# Number of strikes used: 2
# Done in 0.027740478515625 seconds
# 26
# current clue: __________
# guess letter: e
# current clue: _e______e_
# guess letter: r
# current clue: _e______e_
# guess letter: d
# current clue: _e______ed
# guess letter: t
# current clue: _e______ed
# guess letter: l
# current clue: _e___l__ed
# guess letter: n
# current clue: _e___l__ed
# guess letter: s
# current clue: se___l_sed
# guess letter: i
# current clue: se_i_l_sed
# guess letter: o
# current clue: se_i_losed
# guess letter: m
# current clue: semi_losed
# guess letter: a
# current clue: semi_losed
# guess letter: c
# Sucess! The mystery word was: semiclosed
# Number of strikes used: 4
# Done in 0.034101247787475586 seconds
# 27
# current clue: ________
# guess letter: e
# current clue: ______e_
# guess letter: r
# current clue: _____re_
# guess letter: p
# current clue: _____re_
# guess letter: a
# current clue: _____re_
# guess letter: d
# current clue: _____red
# guess letter: o
# current clue: _____red
# guess letter: u
# current clue: ___u_red
# guess letter: n
# current clue: _n_u_red
# guess letter: i
# current clue: in_uired
# guess letter: q
# Sucess! The mystery word was: inquired
# Number of strikes used: 3
# Done in 0.04309487342834473 seconds
# 28
# current clue: ____________
# guess letter: e
# current clue: ____________
# guess letter: i
# current clue: i__i_i___i__
# guess letter: t
# current clue: i_ti_i__ti__
# guess letter: s
# current clue: i_ti_i__ti__
# guess letter: n
# current clue: inti_i__ti_n
# guess letter: o
# current clue: inti_i__tion
# guess letter: a
# current clue: inti_i_ation
# guess letter: c
# current clue: inti_i_ation
# guess letter: l
# current clue: inti_i_ation
# guess letter: m
# current clue: intimi_ation
# guess letter: z
# current clue: intimi_ation
# guess letter: d
# Sucess! The mystery word was: intimidation
# Number of strikes used: 5
# Done in 0.03759431838989258 seconds
# 29
# current clue: ____
# guess letter: a
# current clue: ____
# guess letter: e
# current clue: ____
# guess letter: o
# current clue: ____
# guess letter: s
# current clue: ___s
# guess letter: i
# current clue: ___s
# guess letter: u
# current clue: ___s
# guess letter: t
# Done in 0.02872014045715332 seconds
# 30
# current clue: _______
# guess letter: e
# current clue: ____e__
# guess letter: r
# current clue: ____e__
# guess letter: s
# current clue: s___ess
# guess letter: n
# current clue: s___ess
# guess letter: l
# current clue: s___ess
# guess letter: t
# current clue: s___ess
# guess letter: h
# current clue: s___ess
# guess letter: c
# current clue: s_ccess
# guess letter: a
# Done in 0.0305023193359375 seconds
# 31
# current clue: ____________
# guess letter: e
# current clue: _e_________e
# guess letter: r
# current clue: _e_________e
# guess letter: t
# current clue: _e_________e
# guess letter: n
# current clue: _e_________e
# guess letter: d
# current clue: _e____d__d_e
# guess letter: a
# current clue: _e_a__d__dae
# guess letter: i
# current clue: _e_a__diidae
# guess letter: o
# current clue: _e_a_odiidae
# guess letter: p
# current clue: _e_apodiidae
# guess letter: c
# current clue: _e_apodiidae
# guess letter: v
# current clue: _e_apodiidae
# guess letter: l
# Done in 0.032196998596191406 seconds
# 32
# current clue: ______________
# guess letter: e
# current clue: ______________
# guess letter: i
# current clue: _i__i_i___i___
# guess letter: t
# current clue: _it_i_i__ti___
# guess letter: r
# current clue: _itri_i__ti___
# guess letter: n
# current clue: _itri_i__ti_n_
# guess letter: o
# current clue: _itri_i__tion_
# guess letter: a
# current clue: _itri_i_ation_
# guess letter: c
# current clue: _itri_ication_
# guess letter: f
# current clue: _itrification_
# guess letter: s
# current clue: _itrifications
# guess letter: v
# Sucess! The mystery word was: vitrifications
# Number of strikes used: 1
# Done in 0.029899120330810547 seconds
# 33
# current clue: _____________
# guess letter: e
# current clue: _______e____e
# guess letter: r
# current clue: ______re___re
# guess letter: p
# current clue: _____pre___re
# guess letter: s
# current clue: _____press_re
# guess letter: o
# current clue: ____opress_re
# guess letter: u
# current clue: ____opressure
# guess letter: c
# current clue: ____opressure
# guess letter: t
# current clue: ____opressure
# guess letter: n
# current clue: _n__opressure
# guess letter: i
# current clue: _n_iopressure
# guess letter: g
# current clue: _ngiopressure
# guess letter: a
# Sucess! The mystery word was: angiopressure
# Number of strikes used: 2
# Done in 0.03576064109802246 seconds
# 34
# current clue: _________
# guess letter: e
# current clue: _______e_
# guess letter: r
# current clue: _____r_e_
# guess letter: i
# current clue: _____r_e_
# guess letter: t
# current clue: t____r_e_
# guess letter: s
# current clue: t____r_e_
# guess letter: n
# current clue: t____r_e_
# guess letter: d
# current clue: t____r_ed
# guess letter: a
# current clue: t____r_ed
# guess letter: h
# current clue: t____r_ed
# guess letter: o
# current clue: t_o_or_ed
# guess letter: m
# Done in 0.031078338623046875 seconds
# 35
# current clue: _________
# guess letter: e
# current clue: _________
# guess letter: i
# current clue: ____i_i__
# guess letter: t
# current clue: ____i_it_
# guess letter: l
# current clue: ____ilit_
# guess letter: b
# current clue: ___bilit_
# guess letter: a
# current clue: a_abilit_
# guess letter: r
# current clue: arabilit_
# guess letter: y
# Sucess! The mystery word was: arability
# Number of strikes used: 1
# Done in 0.024077653884887695 seconds
# 36
# current clue: ______
# guess letter: e
# current clue: ____e_
# guess letter: r
# current clue: ____e_
# guess letter: l
# current clue: ____el
# guess letter: s
# current clue: ____el
# guess letter: v
# current clue: ____el
# guess letter: t
# current clue: ____el
# guess letter: w
# current clue: w___el
# guess letter: o
# current clue: w___el
# guess letter: i
# current clue: wi__el
# guess letter: n
# current clue: win_el
# guess letter: g
# Done in 0.031227588653564453 seconds
# 37
# current clue: _________
# guess letter: e
# current clue: ________e
# guess letter: t
# current clue: ________e
# guess letter: r
# current clue: _____r__e
# guess letter: a
# current clue: _____r__e
# guess letter: o
# current clue: o____r__e
# guess letter: i
# current clue: o____ri_e
# guess letter: n
# current clue: o____rine
# guess letter: u
# current clue: o___urine
# guess letter: c
# current clue: o___urine
# guess letter: s
# current clue: o___urine
# guess letter: p
# current clue: o__purine
# guess letter: m
# current clue: o__purine
# guess letter: l
# Done in 0.043884992599487305 seconds
# 38
# current clue: ___________
# guess letter: e
# current clue: ______e____
# guess letter: r
# current clue: ___r__e____
# guess letter: a
# current clue: ___ra_e____
# guess letter: t
# current clue: __tra_e____
# guess letter: s
# current clue: __tra_e____
# guess letter: n
# current clue: _ntra_e____
# guess letter: i
# current clue: intra_e__i_
# guess letter: c
# current clue: intra_e__ic
# guess letter: l
# current clue: intra_el_ic
# guess letter: v
# current clue: intra_elvic
# guess letter: p
# Sucess! The mystery word was: intrapelvic
# Number of strikes used: 1
# Done in 0.02891707420349121 seconds
# 39
# current clue: _____________
# guess letter: e
# current clue: ____e________
# guess letter: r
# current clue: ____e________
# guess letter: n
# current clue: ____e______n_
# guess letter: i
# current clue: ____e_____in_
# guess letter: g
# current clue: ____e_____ing
# guess letter: t
# current clue: ____e_____ing
# guess letter: l
# current clue: _l__e_l___ing
# guess letter: d
# current clue: _l__e_l___ing
# guess letter: a
# current clue: _l__e_l___ing
# guess letter: p
# current clue: pl__epl___ing
# guess letter: o
# current clue: pl__epl___ing
# guess letter: u
# current clue: plu_eplu__ing
# guess letter: m
# current clue: plumeplu__ing
# guess letter: s
# Done in 0.041513681411743164 seconds
# 40
# current clue: _________
# guess letter: e
# current clue: _______e_
# guess letter: r
# current clue: __r____er
# guess letter: t
# current clue: __r____er
# guess letter: p
# current clue: __rp___er
# guess letter: o
# current clue: __rp___er
# guess letter: a
# current clue: a_rp_a_er
# guess letter: i
# current clue: airp_a_er
# guess letter: l
# current clue: airpla_er
# guess letter: n
# Sucess! The mystery word was: airplaner
# Number of strikes used: 2
# Done in 0.02694392204284668 seconds
# 41
# current clue: _________
# guess letter: e
# current clue: ___e____e
# guess letter: r
# current clue: ___err__e
# guess letter: i
# current clue: ___err__e
# guess letter: a
# current clue: ___erra_e
# guess letter: t
# current clue: ___erra_e
# guess letter: n
# current clue: ___erra_e
# guess letter: c
# current clue: ___errace
# guess letter: v
# current clue: ___errace
# guess letter: b
# current clue: ___errace
# guess letter: f
# Done in 0.031222105026245117 seconds
# 42
# current clue: ________
# guess letter: e
# current clue: ____e__e
# guess letter: r
# current clue: ____e__e
# guess letter: l
# current clue: ____e__e
# guess letter: s
# current clue: s___e__e
# guess letter: t
# current clue: s___e__e
# guess letter: n
# current clue: s__ne__e
# guess letter: i
# current clue: s__ne__e
# guess letter: o
# current clue: s__ne__e
# guess letter: d
# Done in 0.03802490234375 seconds
# 43
# current clue: _____
# guess letter: a
# current clue: _____
# guess letter: e
# current clue: _____
# guess letter: s
# current clue: _____
# guess letter: o
# current clue: _____
# guess letter: r
# current clue: _____
# guess letter: i
# current clue: _i__i
# guess letter: n
# Done in 0.03288531303405762 seconds
# 44
# current clue: ________
# guess letter: e
# current clue: ___e___e
# guess letter: r
# current clue: __re___e
# guess letter: p
# current clue: __re___e
# guess letter: a
# current clue: __re___e
# guess letter: d
# current clue: __re___e
# guess letter: s
# current clue: __re___e
# guess letter: t
# current clue: t_re___e
# guess letter: u
# current clue: t_re___e
# guess letter: o
# Done in 0.026541709899902344 seconds
# 45
# current clue: _______
# guess letter: e
# current clue: ____e__
# guess letter: r
# current clue: ____e__
# guess letter: s
# current clue: ___se__
# guess letter: i
# current clue: ___se__
# guess letter: n
# current clue: ___se__
# guess letter: o
# current clue: ___se__
# guess letter: u
# current clue: ___se__
# guess letter: a
# current clue: __ase__
# guess letter: l
# Done in 0.028966426849365234 seconds
# 46
# current clue: _________
# guess letter: e
# current clue: _________
# guess letter: i
# current clue: _________
# guess letter: a
# current clue: ____a____
# guess letter: r
# current clue: ____a__r_
# guess letter: o
# current clue: ____a_or_
# guess letter: t
# current clue: ____ator_
# guess letter: m
# current clue: __mmator_
# guess letter: u
# current clue: _ummator_
# guess letter: s
# current clue: summator_
# guess letter: y
# Sucess! The mystery word was: summatory
# Number of strikes used: 2
# Done in 0.03767657279968262 seconds
# 47
# current clue: ________
# guess letter: e
# current clue: ________
# guess letter: a
# current clue: ___a____
# guess letter: r
# current clue: __ra____
# guess letter: t
# current clue: __ra____
# guess letter: g
# current clue: __ra____
# guess letter: c
# current clue: _cra_c__
# guess letter: n
# current clue: _cra_c__
# guess letter: s
# current clue: scra_c_s
# guess letter: u
# current clue: scra_c_s
# guess letter: i
# current clue: scraic_s
# guess letter: k
# Done in 0.03942728042602539 seconds
# 48
# current clue: _____
# guess letter: a
# current clue: __a__
# guess letter: r
# current clue: r_a__
# guess letter: i
# current clue: r_a__
# guess letter: e
# current clue: rea_e
# guess letter: t
# current clue: rea_e
# guess letter: d
# current clue: rea_e
# guess letter: s
# current clue: rea_e
# guess letter: v
# current clue: rea_e
# guess letter: k
# Done in 0.021933794021606445 seconds
# 49
# current clue: ___________
# guess letter: e
# current clue: _________e_
# guess letter: r
# current clue: _____r___e_
# guess letter: a
# current clue: _____r___e_
# guess letter: o
# current clue: ____or___e_
# guess letter: t
# current clue: ____ort__e_
# guess letter: h
# current clue: ____ort__e_
# guess letter: i
# current clue: _i__ort__e_
# guess letter: s
# current clue: _is_ort__es
# guess letter: p
# current clue: _is_ort__es
# guess letter: c
# current clue: _is_ort__es
# guess letter: m
# current clue: mis_ort__es
# guess letter: w
# current clue: mis_ort__es
# guess letter: f
# current clue: misfort__es
# guess letter: u
# current clue: misfortu_es
# guess letter: n
# Sucess! The mystery word was: misfortunes
# Number of strikes used: 5
# Done in 0.05247306823730469 seconds
# 50
# current clue: _________
# guess letter: e
# current clue: _________
# guess letter: i
# current clue: _______i_
# guess letter: n
# current clue: _______i_
# guess letter: t
# current clue: _______i_
# guess letter: s
# current clue: _______i_
# guess letter: l
# current clue: ___l___i_
# guess letter: a
# current clue: ___l___i_
# guess letter: o
# current clue: ___lo_oi_
# guess letter: r
# Done in 0.026154279708862305 seconds
# 51
# current clue: ___________
# guess letter: e
# current clue: __________e
# guess letter: t
# current clue: _________te
# guess letter: a
# current clue: a__a____ate
# guess letter: r
# current clue: a_ra____ate
# guess letter: c
# current clue: a_ra_c__ate
# guess letter: n
# current clue: a_ranc__ate
# guess letter: g
# current clue: a_ranc__ate
# guess letter: b
# current clue: abranc__ate
# guess letter: h
# current clue: abranch_ate
# guess letter: i
# Sucess! The mystery word was: abranchiate
# Number of strikes used: 1
# Done in 0.031215667724609375 seconds
# 52
# current clue: ______________
# guess letter: e
# current clue: _e____e_______
# guess letter: r
# current clue: re_r__e_______
# guess letter: t
# current clue: retr__e_______
# guess letter: a
# current clue: retr__e_____a_
# guess letter: i
# current clue: retr__e__i__a_
# guess letter: o
# current clue: retro_e__io_a_
# guess letter: n
# current clue: retro_e__iona_
# guess letter: s
# current clue: retro_essiona_
# guess letter: l
# current clue: retro_essional
# guess letter: c
# Sucess! The mystery word was: retrocessional
# Number of strikes used: 0
# Done in 0.030050039291381836 seconds
# 53
# current clue: __________
# guess letter: e
# current clue: _e________
# guess letter: r
# current clue: _e______r_
# guess letter: a
# current clue: _ea_____r_
# guess letter: l
# current clue: _eal____r_
# guess letter: i
# current clue: _eal____r_
# guess letter: t
# current clue: _eal____r_
# guess letter: o
# current clue: _eal____r_
# guess letter: s
# current clue: _eal_s__r_
# guess letter: d
# current clue: _ealds__r_
# guess letter: h
# current clue: healds__r_
# guess letter: m
# current clue: healds__r_
# guess letter: b
# current clue: healdsb_r_
# guess letter: u
# current clue: healdsbur_
# guess letter: g
# Sucess! The mystery word was: healdsburg
# Number of strikes used: 4
# Done in 0.03889107704162598 seconds
# 54
# current clue: _________
# guess letter: e
# current clue: _____e___
# guess letter: r
# current clue: _____e___
# guess letter: s
# current clue: _____e___
# guess letter: d
# current clue: _____e___
# guess letter: n
# current clue: _____e___
# guess letter: l
# current clue: __l__e___
# guess letter: a
# current clue: _al_ae__a
# guess letter: i
# current clue: _al_ae_ia
# guess letter: m
# current clue: _al_aemia
# guess letter: h
# current clue: _al_aemia
# guess letter: c
# Sucess! The mystery word was: calcaemia
# Number of strikes used: 5
# Done in 0.032975196838378906 seconds
# 55
# current clue: _______
# guess letter: e
# current clue: ______e
# guess letter: l
# current clue: ______e
# guess letter: r
# current clue: ______e
# guess letter: t
# current clue: ______e
# guess letter: n
# current clue: ___n_ne
# guess letter: o
# current clue: ___n_ne
# guess letter: i
# current clue: ___nine
# guess letter: a
# current clue: __anine
# guess letter: m
# current clue: __anine
# guess letter: c
# current clue: c_anine
# guess letter: h
# Done in 0.029700040817260742 seconds
# 56
# current clue: ______________
# guess letter: e
# current clue: __________e_e_
# guess letter: n
# current clue: __________e_e_
# guess letter: r
# current clue: ___r____r_ere_
# guess letter: t
# current clue: ___rt___rtere_
# guess letter: a
# current clue: ___rt__artere_
# guess letter: o
# current clue: __ort__artere_
# guess letter: h
# current clue: _hort__artere_
# guess letter: p
# current clue: _hort__artere_
# guess letter: s
# current clue: short__artere_
# guess letter: i
# current clue: short__artere_
# guess letter: u
# current clue: short_uartere_
# guess letter: q
# current clue: shortquartere_
# guess letter: d
# Sucess! The mystery word was: shortquartered
# Number of strikes used: 3
# Done in 0.04037308692932129 seconds
# 57
# current clue: ________________
# guess letter: e
# current clue: _e_______e___e__
# guess letter: r
# current clue: _e_______er__e__
# guess letter: t
# current clue: _e______ter_te__
# guess letter: a
# current clue: _e______terate__
# guess letter: n
# current clue: _e______terate__
# guess letter: s
# current clue: se______terate__
# guess letter: d
# current clue: se______terate__
# guess letter: l
# current clue: se___ll_teratel_
# guess letter: i
# current clue: se_iilliteratel_
# guess letter: m
# current clue: semiilliteratel_
# guess letter: y
# Sucess! The mystery word was: semiilliterately
# Number of strikes used: 2
# Done in 0.03554677963256836 seconds
# 58
# current clue: _____________
# guess letter: e
# current clue: _e_e_________
# guess letter: n
# current clue: _ene_________
# guess letter: s
# current clue: _ene_________
# guess letter: r
# current clue: _ene_r_______
# guess letter: t
# current clue: _enetr_t___t_
# guess letter: a
# current clue: _enetrat___t_
# guess letter: i
# current clue: _enetrati_it_
# guess letter: l
# current clue: _enetrati_it_
# guess letter: v
# current clue: _enetrativit_
# guess letter: y
# current clue: _enetrativity
# guess letter: g
# current clue: _enetrativity
# guess letter: p
# Sucess! The mystery word was: penetrativity
# Number of strikes used: 3
# Done in 0.037169456481933594 seconds
# 59
# current clue: ______________
# guess letter: e
# current clue: _e___e________
# guess letter: r
# current clue: _e__re________
# guess letter: p
# current clue: _e__re________
# guess letter: a
# current clue: _e__re________
# guess letter: d
# current clue: _e__re____d___
# guess letter: s
# current clue: _e__res___d___
# guess letter: t
# current clue: _e__res___d___
# guess letter: o
# current clue: _e__reso__d___
# guess letter: n
# current clue: _e__reso_nd_n_
# guess letter: u
# current clue: _e__resound_n_
# guess letter: i
# current clue: _e__resoundin_
# guess letter: g
# current clue: _e__resounding
# guess letter: c
# current clue: _e__resounding
# guess letter: f
# current clue: _e__resounding
# guess letter: b
# Done in 0.03645682334899902 seconds
# 60
# current clue: __________
# guess letter: e
# current clue: _______e__
# guess letter: r
# current clue: _r_____e__
# guess letter: a
# current clue: _ra____ea_
# guess letter: t
# current clue: _ra____ea_
# guess letter: d
# current clue: dra____ead
# guess letter: h
# current clue: dra___head
# guess letter: c
# current clue: dra___head
# guess letter: s
# current clue: dra___head
# guess letter: p
# current clue: dra___head
# guess letter: n
# current clue: dra__nhead
# guess letter: u
# current clue: dra__nhead
# guess letter: i
# Done in 0.03820610046386719 seconds
# 61
# current clue: ___________
# guess letter: e
# current clue: e__________
# guess letter: r
# current clue: e__________
# guess letter: d
# current clue: e__________
# guess letter: s
# current clue: e__________
# guess letter: n
# current clue: e__________
# guess letter: l
# current clue: e___l_l_l__
# guess letter: i
# current clue: e___l_l_li_
# guess letter: a
# current clue: e___l_lalia
# guess letter: o
# current clue: e__ololalia
# guess letter: c
# current clue: e__ololalia
# guess letter: h
# Done in 0.025854110717773438 seconds
# 62
# current clue: ____________
# guess letter: e
# current clue: ____________
# guess letter: i
# current clue: ___i______i_
# guess letter: n
# current clue: ___i____n_i_
# guess letter: t
# current clue: ___i_t__n_it
# guess letter: s
# current clue: ___i_t__nsit
# guess letter: a
# current clue: _a_i_t_ansit
# guess letter: r
# current clue: ra_i_transit
# guess letter: l
# current clue: ra_i_transit
# guess letter: o
# current clue: ra_i_transit
# guess letter: c
# current clue: ra_i_transit
# guess letter: d
# current clue: ra_idtransit
# guess letter: m
# current clue: ra_idtransit
# guess letter: p
# Sucess! The mystery word was: rapidtransit
# Number of strikes used: 5
# Done in 0.0453648567199707 seconds
# 63
# current clue: ________
# guess letter: e
# current clue: ____e___
# guess letter: r
# current clue: ____er__
# guess letter: t
# current clue: ____er__
# guess letter: s
# current clue: ____er__
# guess letter: i
# current clue: ____er__
# guess letter: p
# current clue: ____er__
# guess letter: v
# current clue: ____er__
# guess letter: a
# current clue: _a__er__
# guess letter: m
# Done in 0.032263994216918945 seconds
# 64
# current clue: _________
# guess letter: e
# current clue: _______e_
# guess letter: r
# current clue: _______er
# guess letter: t
# current clue: _______er
# guess letter: p
# current clue: _______er
# guess letter: v
# current clue: _______er
# guess letter: d
# current clue: _______er
# guess letter: h
# current clue: _______er
# guess letter: l
# current clue: __l____er
# guess letter: b
# current clue: __l__b_er
# guess letter: s
# Done in 0.024600505828857422 seconds
# 65
# current clue: ____________
# guess letter: e
# current clue: _e________e_
# guess letter: r
# current clue: _e___r___re_
# guess letter: p
# current clue: _e___r___re_
# guess letter: a
# current clue: _e___r___re_
# guess letter: d
# current clue: _e___r___re_
# guess letter: s
# current clue: _e___r_s_res
# guess letter: t
# current clue: te___r_stres
# guess letter: i
# current clue: te__ir_stres
# guess letter: o
# current clue: te__irostres
# guess letter: n
# current clue: ten_irostres
# guess letter: c
# current clue: ten_irostres
# guess letter: v
# current clue: ten_irostres
# guess letter: g
# Done in 0.03738903999328613 seconds
# 66
# current clue: ____
# guess letter: a
# current clue: _a__
# guess letter: r
# current clue: _a__
# guess letter: l
# current clue: _a__
# guess letter: n
# current clue: na__
# guess letter: t
# current clue: nat_
# guess letter: i
# current clue: nat_
# guess letter: e
# current clue: nat_
# guess letter: o
# current clue: nat_
# guess letter: h
# Done in 0.022141218185424805 seconds
# 67
# current clue: _________
# guess letter: e
# current clue: ______e__
# guess letter: r
# current clue: ______e__
# guess letter: s
# current clue: s_____ess
# guess letter: n
# current clue: s_____ess
# guess letter: l
# current clue: s__l_less
# guess letter: t
# current clue: st_l_less
# guess letter: a
# current clue: stal_less
# guess letter: i
# current clue: stal_less
# guess letter: o
# current clue: stal_less
# guess letter: k
# Sucess! The mystery word was: stalkless
# Number of strikes used: 4
# Done in 0.03683805465698242 seconds
# 68
# current clue: _________
# guess letter: e
# current clue: _________
# guess letter: i
# current clue: _i_______
# guess letter: n
# current clue: _i_______
# guess letter: t
# current clue: _i_______
# guess letter: s
# current clue: _is______
# guess letter: m
# current clue: _is______
# guess letter: h
# current clue: _ish_____
# guess letter: l
# current clue: _ish____l
# guess letter: a
# current clue: _ish____l
# guess letter: o
# current clue: _isho___l
# guess letter: r
# Done in 0.04315924644470215 seconds
# 69
# current clue: _____
# guess letter: a
# current clue: _____
# guess letter: e
# current clue: _____
# guess letter: s
# current clue: _____
# guess letter: o
# current clue: ___o_
# guess letter: r
# current clue: ___o_
# guess letter: n
# current clue: ___o_
# guess letter: l
# current clue: __lo_
# guess letter: g
# Done in 0.027593374252319336 seconds
# 70
# current clue: _____________
# ...
# guess letter: t
# current clue: _e______r___e
# guess letter: a
# current clue: _e______r___e
# guess letter: o
# current clue: _e____o_r___e
# guess letter: g
# current clue: _e_g__o_r___e
# guess letter: n
# current clue: ne_g__o_r___e
# guess letter: s
# current clue: ne_g__o_r___e
# guess letter: i
# current clue: neig__o_r_i_e
# guess letter: h
# current clue: neigh_o_r_i_e
# guess letter: b
# current clue: neighbo_r_i_e
# guess letter: u
# current clue: neighbour_i_e
# guess letter: d
# current clue: neighbour_i_e
# guess letter: l
# current clue: neighbourli_e
# guess letter: k
# Sucess! The mystery word was: neighbourlike
# Number of strikes used: 4
# Done in 0.04044818878173828 seconds
# 71
# current clue: __________
# guess letter: e
# current clue: __________
# guess letter: i
# current clue: ________i_
# guess letter: n
# current clue: ________in
# guess letter: t
# current clue: __t_____in
# guess letter: l
# current clue: __t_____in
# guess letter: r
# current clue: __t_____in
# guess letter: m
# current clue: __t_m___in
# guess letter: o
# current clue: __tom_o_in
# guess letter: p
# current clue: __tom_o_in
# guess letter: a
# current clue: a_tom_o_in
# guess letter: s
# current clue: a_tom_osin
# guess letter: y
# current clue: a_tomyosin
# guess letter: c
# Sucess! The mystery word was: actomyosin
# Number of strikes used: 4
# Done in 0.02470874786376953 seconds
# 72
# current clue: _________
# guess letter: e
# current clue: _________
# guess letter: i
# current clue: i_____i__
# guess letter: n
# current clue: i_____i_n
# guess letter: o
# current clue: i___o_ion
# guess letter: t
# current clue: i___o_ion
# guess letter: s
# current clue: i___osion
# guess letter: r
# current clue: i___osion
# guess letter: l
# current clue: i__losion
# guess letter: c
# current clue: i__losion
# guess letter: a
# current clue: i__losion
# guess letter: u
# Done in 0.03981804847717285 seconds
# 73
# current clue: ___________
# guess letter: e
# current clue: ___________
# guess letter: i
# current clue: ______i____
# guess letter: n
# current clue: n_n___in___
# guess letter: o
# current clue: non___ino__
# guess letter: t
# current clue: non___ino__
# guess letter: s
# current clue: non___ino_s
# guess letter: u
# current clue: non_u_inous
# guess letter: m
# current clue: non_uminous
# guess letter: l
# Sucess! The mystery word was: nonluminous
# Number of strikes used: 2
# Done in 0.03412365913391113 seconds
# 74
# current clue: ______________
# guess letter: e
# current clue: _____e________
# guess letter: r
# current clue: _____e________
# guess letter: n
# current clue: _n___e___n____
# guess letter: o
# current clue: _n___e___n____
# guess letter: i
# current clue: _n_i_e__in__i_
# guess letter: t
# current clue: _nti_e__int_i_
# guess letter: a
# current clue: anti_e__int_i_
# guess letter: h
# current clue: antihe__inthi_
# guess letter: m
# current clue: antihe_minthi_
# guess letter: l
# current clue: antihelminthi_
# guess letter: c
# Sucess! The mystery word was: antihelminthic
# Number of strikes used: 2
# Done in 0.027754545211791992 seconds
# 75
# current clue: ________
# guess letter: e
# current clue: ________
# guess letter: a
# current clue: __a_____
# guess letter: r
# current clue: __a_____
# guess letter: n
# current clue: __a___n_
# guess letter: i
# current clue: __a__in_
# guess letter: g
# current clue: __a__ing
# guess letter: t
# current clue: __atting
# guess letter: l
# current clue: __atting
# guess letter: c
# current clue: __atting
# guess letter: m
# current clue: __atting
# guess letter: b
# Done in 0.03260993957519531 seconds
# 76
# current clue: _______
# guess letter: e
# current clue: _____e_
# guess letter: r
# current clue: _____e_
# guess letter: s
# current clue: ___s_e_
# guess letter: t
# current clue: ___s_e_
# guess letter: h
# current clue: ___s_e_
# guess letter: p
# current clue: ___s_e_
# guess letter: n
# current clue: __ns_e_
# guess letter: i
# current clue: _ins_e_
# guess letter: c
# current clue: _ins_e_
# guess letter: l
# current clue: lins_e_
# guess letter: u
# Done in 0.03402376174926758 seconds
# 77
# current clue: ______________
# guess letter: e
# current clue: __e__________e
# guess letter: r
# current clue: __er_________e
# guess letter: t
# current clue: __er_________e
# guess letter: s
# current clue: __er_________e
# guess letter: i
# current clue: __eri___i____e
# guess letter: n
# current clue: __erin__in___e
# guess letter: g
# current clue: __erin__in___e
# guess letter: d
# current clue: __erin__in___e
# guess letter: a
# current clue: __erin__ina__e
# guess letter: l
# current clue: __erin_lina_le
# guess letter: b
# current clue: __erin_linable
# guess letter: o
# current clue: o_erin_linable
# guess letter: c
# current clue: o_erinclinable
# guess letter: v
# Sucess! The mystery word was: overinclinable
# Number of strikes used: 4
# Done in 0.03829455375671387 seconds
# 78
# current clue: _______________
# guess letter: i
# current clue: ___________i___
# guess letter: t
# current clue: ___________i___
# guess letter: n
# current clue: _________n_i___
# guess letter: d
# current clue: _________ndi__d
# guess letter: a
# current clue: ____a___andi__d
# guess letter: s
# current clue: s___a___andi__d
# guess letter: c
# current clue: s___a___andi__d
# guess letter: l
# current clue: s_l_a___andi__d
# guess letter: e
# current clue: sel_a___andi_ed
# guess letter: f
# current clue: selfa___andi_ed
# guess letter: z
# current clue: selfa___andized
# guess letter: r
# current clue: selfa__randized
# guess letter: b
# current clue: selfa__randized
# guess letter: g
# Sucess! The mystery word was: selfaggrandized
# Number of strikes used: 3
# Done in 0.04454636573791504 seconds
# 79
# current clue: ________
# guess letter: e
# current clue: ______e_
# guess letter: r
# current clue: ______e_
# guess letter: s
# current clue: s_____e_
# guess letter: t
# current clue: s_____e_
# guess letter: l
# current clue: s_____e_
# guess letter: n
# current clue: s_n___e_
# guess letter: i
# current clue: s_n___e_
# guess letter: o
# current clue: s_n___e_
# guess letter: a
# current clue: s_na__ea
# guess letter: y
# current clue: syna__ea
# guess letter: m
# Done in 0.029595136642456055 seconds
# 80
# current clue: _______
# guess letter: e
# current clue: _______
# guess letter: a
# current clue: __a___a
# guess letter: r
# current clue: __a___a
# guess letter: l
# current clue: __a___a
# guess letter: n
# current clue: __a___a
# guess letter: t
# current clue: __a___a
# guess letter: m
# current clue: __a__ma
# guess letter: o
# Done in 0.03432011604309082 seconds
# 81
# current clue: ________
# guess letter: e
# current clue: ________
# guess letter: a
# current clue: __a__a__
# guess letter: r
# current clue: _ra__a__
# guess letter: t
# current clue: _ra__a__
# guess letter: g
# current clue: _ra__a__
# guess letter: c
# current clue: _ra__a_c
# guess letter: n
# current clue: _ra__a_c
# guess letter: l
# current clue: _ra__a_c
# guess letter: s
# Done in 0.031694650650024414 seconds
# 82
# current clue: ____________
# guess letter: e
# current clue: ___e___e____
# guess letter: r
# current clue: ___er__e___r
# guess letter: t
# current clue: __ter_te___r
# guess letter: a
# current clue: __ter_te__ar
# guess letter: i
# current clue: i_ter_te__ar
# guess letter: s
# current clue: i_terste__ar
# guess letter: n
# current clue: interste__ar
# guess letter: d
# current clue: interste__ar
# guess letter: l
# Sucess! The mystery word was: interstellar
# Number of strikes used: 1
# Done in 0.03573870658874512 seconds
# 83
# current clue: _______
# guess letter: e
# current clue: __e___e
# guess letter: r
# current clue: _re___e
# guess letter: p
# current clue: _re___e
# guess letter: a
# current clue: _re_a_e
# guess letter: t
# current clue: tre_a_e
# guess letter: m
# current clue: tre_a_e
# guess letter: s
# current clue: tre_a_e
# guess letter: n
# current clue: tre_a_e
# guess letter: l
# current clue: tre_a_e
# guess letter: c
# Done in 0.03003072738647461 seconds
# 84
# current clue: _______________
# guess letter: i
# current clue: i____i_________
# guess letter: n
# current clue: in___i_____n___
# guess letter: g
# current clue: in___i_____n___
# guess letter: e
# current clue: in___i____ene__
# guess letter: s
# current clue: in___i____eness
# guess letter: l
# current clue: in___i___leness
# guess letter: b
# current clue: in__bi__bleness
# guess letter: a
# current clue: in__bi_ableness
# guess letter: t
# current clue: in__bitableness
# guess letter: r
# current clue: in__bitableness
# guess letter: u
# current clue: in_ubitableness
# guess letter: c
# current clue: in_ubitableness
# guess letter: d
# Sucess! The mystery word was: indubitableness
# Number of strikes used: 3
# Done in 0.035149574279785156 seconds
# 85
# current clue: _________
# guess letter: e
# current clue: _______e_
# guess letter: r
# current clue: _______e_
# guess letter: s
# current clue: _______es
# guess letter: n
# current clue: _____n_es
# guess letter: t
# current clue: t____n_es
# guess letter: i
# current clue: t____nies
# guess letter: o
# current clue: t____nies
# guess letter: a
# current clue: t___anies
# guess letter: m
# current clue: t_m_anies
# guess letter: p
# current clue: t_mpanies
# guess letter: y
# Sucess! The mystery word was: tympanies
# Number of strikes used: 2
# Done in 0.025878190994262695 seconds
# 86
# current clue: _______
# guess letter: e
# current clue: ______e
# guess letter: l
# current clue: _____le
# guess letter: b
# current clue: _____le
# guess letter: a
# current clue: _____le
# guess letter: p
# current clue: _____le
# guess letter: o
# current clue: ____ole
# guess letter: h
# current clue: ___hole
# guess letter: c
# current clue: __chole
# guess letter: n
# current clue: n_chole
# guess letter: i
# Sucess! The mystery word was: nichole
# Number of strikes used: 3
# Done in 0.032233476638793945 seconds
# 87
# current clue: ________
# guess letter: e
# current clue: __e__e__
# guess letter: r
# current clue: _re__e__
# guess letter: p
# current clue: _re__e__
# guess letter: a
# current clue: _re__e__
# guess letter: d
# current clue: _re__e__
# guess letter: s
# current clue: _res_es_
# guess letter: t
# current clue: _res_est
# guess letter: i
# current clue: _res_est
# guess letter: c
# current clue: _res_est
# guess letter: h
# current clue: _reshest
# guess letter: o
# Done in 0.03256559371948242 seconds
# 88
# current clue: ________________
# guess letter: e
# current clue: _______________e
# guess letter: n
# current clue: _________n_____e
# guess letter: o
# current clue: _____o___n_____e
# guess letter: i
# current clue: _____o___n__i__e
# guess letter: t
# current clue: ____to___n__i__e
# guess letter: r
# current clue: _r__to_r_n__i__e
# guess letter: a
# current clue: _r__to_ran__i_ae
# guess letter: g
# current clue: _r__to_ran__i_ae
# guess letter: c
# current clue: cr__to_ranc_i_ae
# guess letter: h
# current clue: cr__to_ranchi_ae
# guess letter: u
# current clue: cr__to_ranchi_ae
# guess letter: d
# current clue: cr__to_ranchidae
# guess letter: b
# current clue: cr__tobranchidae
# guess letter: y
# current clue: cry_tobranchidae
# guess letter: p
# Sucess! The mystery word was: cryptobranchidae
# Number of strikes used: 2
# Done in 0.03298497200012207 seconds
# 89
# current clue: ______
# guess letter: e
# current clue: ______
# guess letter: a
# current clue: _a___a
# guess letter: r
# current clue: _a___a
# guess letter: n
# current clue: _a___a
# guess letter: l
# current clue: _a___a
# guess letter: m
# current clue: _a__ma
# guess letter: o
# current clue: _a__ma
# guess letter: i
# Done in 0.03086090087890625 seconds
# 90
# current clue: _________
# guess letter: e
# current clue: _e___e___
# guess letter: r
# current clue: _e_r_e___
# guess letter: t
# current clue: _e_r_e___
# guess letter: a
# current clue: _e_rae__a
# guess letter: b
# current clue: _e_rae__a
# guess letter: g
# current clue: _e_rae__a
# guess letter: u
# current clue: _e_rae__a
# guess letter: c
# current clue: _ecrae__a
# guess letter: s
# current clue: _ecrae__a
# guess letter: n
# current clue: necrae__a
# guess letter: m
# current clue: necraem_a
# guess letter: i
# Sucess! The mystery word was: necraemia
# Number of strikes used: 5
# Done in 0.033176422119140625 seconds
# 91
# current clue: ________
# guess letter: e
# current clue: ________
# guess letter: a
# current clue: ________
# guess letter: i
# current clue: __i___i_
# guess letter: n
# current clue: __i___i_
# guess letter: l
# current clue: __i___i_
# guess letter: t
# current clue: t_i___i_
# guess letter: r
# current clue: tri___ir
# guess letter: c
# current clue: tri___ir
# guess letter: p
# Done in 0.032715797424316406 seconds
# 92
# current clue: ___________
# guess letter: e
# current clue: ___________
# guess letter: i
# current clue: ____i______
# guess letter: n
# current clue: ____i______
# guess letter: t
# current clue: ___ti__t___
# guess letter: a
# current clue: _a_ti_at___
# guess letter: c
# current clue: ca_ti_at___
# guess letter: s
# current clue: casti_at__s
# guess letter: g
# current clue: castigat__s
# guess letter: o
# current clue: castigato_s
# guess letter: r
# Sucess! The mystery word was: castigators
# Number of strikes used: 2
# Done in 0.027012348175048828 seconds
# 93
# current clue: ________
# guess letter: e
# current clue: _______e
# guess letter: r
# current clue: ___r___e
# guess letter: a
# current clue: __ar___e
# guess letter: i
# current clue: __ar_i_e
# guess letter: t
# current clue: __arti_e
# guess letter: v
# current clue: __arti_e
# guess letter: n
# current clue: __arti_e
# guess letter: c
# current clue: __arti_e
# guess letter: s
# current clue: __arti_e
# guess letter: l
# current clue: __artile
# guess letter: p
# current clue: __artile
# guess letter: m
# Done in 0.04085278511047363 seconds
# 94
# current clue: __________
# guess letter: e
# current clue: __e_______
# guess letter: r
# current clue: __e_r_____
# guess letter: a
# current clue: __e_r_____
# guess letter: t
# current clue: __e_r____t
# guess letter: u
# current clue: __eur____t
# guess letter: n
# current clue: __eur___nt
# guess letter: o
# current clue: __euro_ont
# guess letter: l
# current clue: _leuro_ont
# guess letter: p
# current clue: pleuro_ont
# guess letter: c
# current clue: pleuro_ont
# guess letter: d
# Sucess! The mystery word was: pleurodont
# Number of strikes used: 2
# Done in 0.04236102104187012 seconds
# 95
# current clue: _____________
# guess letter: e
# current clue: e___e________
# guess letter: r
# current clue: e___e________
# guess letter: n
# current clue: e___e_______n
# guess letter: s
# current clue: e___e_______n
# guess letter: d
# current clue: e___e_______n
# guess letter: l
# current clue: e___e_______n
# guess letter: t
# current clue: e___e____t__n
# guess letter: i
# current clue: e___e_i__ti_n
# guess letter: o
# current clue: e___e_i__tion
# guess letter: a
# current clue: e___e_i_ation
# guess letter: c
# current clue: e___e_i_ation
# guess letter: z
# current clue: e___e_ization
# guess letter: m
# current clue: e___emization
# guess letter: h
# current clue: e__hemization
# guess letter: p
# current clue: e_phemization
# guess letter: u
# Sucess! The mystery word was: euphemization
# Number of strikes used: 5
# Done in 0.03216409683227539 seconds
# 96
# current clue: ________
# guess letter: e
# current clue: _e______
# guess letter: r
# current clue: re______
# guess letter: s
# current clue: res_____
# guess letter: t
# current clue: res_t___
# guess letter: i
# current clue: resiti__
# guess letter: o
# current clue: resiti__
# guess letter: v
# current clue: resiti__
# guess letter: c
# current clue: resiti__
# guess letter: n
# current clue: resitin_
# guess letter: g
# Sucess! The mystery word was: resiting
# Number of strikes used: 3
# Done in 0.03713345527648926 seconds
# 97
# current clue: _______
# guess letter: e
# current clue: ____e__
# guess letter: r
# current clue: ____er_
# guess letter: t
# current clue: ____er_
# guess letter: s
# current clue: ____er_
# guess letter: i
# current clue: ____er_
# guess letter: p
# current clue: p___er_
# guess letter: v
# current clue: p___er_
# guess letter: a
# current clue: p_a_era
# guess letter: h
# current clue: pha_era
# guess letter: l
# Sucess! The mystery word was: phalera
# Number of strikes used: 4
# Done in 0.030660629272460938 seconds
# 98
# current clue: __________
# guess letter: e
# current clue: _____ee_e_
# guess letter: r
# current clue: __r__ee_e_
# guess letter: n
# current clue: __r__ee_e_
# guess letter: l
# current clue: __r__eele_
# guess letter: h
# current clue: __r_heele_
# guess letter: c
# current clue: c_r_heele_
# guess letter: t
# current clue: c_r_heele_
# guess letter: s
# current clue: c_r_heele_
# guess letter: w
# current clue: c_r_heele_
# guess letter: p
# current clue: c_r_heele_
# guess letter: a
# Done in 0.03229165077209473 seconds
# 99
# current clue: _______
# guess letter: e
# current clue: _ee__e_
# guess letter: r
# current clue: _ee__e_
# guess letter: n
# current clue: _ee__e_
# guess letter: d
# current clue: _ee__ed
# guess letter: t
# current clue: teet_ed
# guess letter: h
# Sucess! The mystery word was: teethed
# Number of strikes used: 2
# Done in 0.03402352333068848 seconds
# Accuracy of the algorithm:  55.00000000000001

# %% [markdown]
# # **Hurrah! I got 55% Accuracy**
